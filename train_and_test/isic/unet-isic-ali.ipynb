# %% [markdown]
# # UNet - ISIC2018
# ---

# %%
# !pip install torchmetrics==0.10.3

# %% [markdown]
# ## Import packages & functions

# %%
from __future__ import print_function, division


import os
import sys
sys.path.append('../..')
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

import copy
import json
import importlib
import glob
import pandas as pd
from skimage import io, transform
import matplotlib.pyplot as plt
from matplotlib.image import imread
import numpy as np
from tqdm import tqdm

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchmetrics
from torch.optim import Adam, SGD
from losses import DiceLoss, DiceLossWithLogtis
from torch.nn import BCELoss, CrossEntropyLoss

from utils import (
    show_sbs,
    load_config,
    _print,
)

# Ignore warnings
import warnings
warnings.filterwarnings("ignore")

# plt.ion()   # interactive mode

# %% [markdown]
# ## Set the seed

# %%
torch.manual_seed(0)
np.random.seed(0)
torch.cuda.manual_seed(0)
import random
random.seed(0)

# %% [markdown]
# ## Load the config

# %%
CONFIG_NAME = "isic/isic2018_unet.yaml"
CONFIG_FILE_PATH = os.path.join("../../configs", CONFIG_NAME)

# %%
config = load_config(CONFIG_FILE_PATH)
_print("Config:", "info_underline")
print(json.dumps(config, indent=2))
print(20*"~-", "\n")
# Out:
# Config:
# {
#   "run": {
#     "mode": "train",
#     "device": "gpu"
#   },
#   "transforms": "none",
#   "dataset": {
#     "class_name": "ISIC2018Dataset",
#     "input_size": 224,
#     "training": {
#       "params": {
#         "data_dir": "/raid/home/labusermodaresi/datasets/ISIC2018"
#       }
#     },
#     "validation": {
#       "params": {
#         "data_dir": "/raid/home/labusermodaresi/datasets/ISIC2018"
#       }
#     },
#     "number_classes": 2
#   },
#   "data_loader": {
#     "train": {
#       "batch_size": 16,
#       "shuffle": true,
#       "num_workers": 8,
#       "pin_memory": true
#     },
#     "validation": {
#       "batch_size": 16,
#       "shuffle": false,
#       "num_workers": 8,
#       "pin_memory": true
#     },
#     "test": {
#       "batch_size": 16,
#       "shuffle": false,
#       "num_workers": 4,
#       "pin_memory": false
#     }
#   },
#   "training": {
#     "optimizer": {
#       "name": "Adam",
#       "params": {
#         "lr": 0.0001
#       }
#     },
#     "criterion": {
#       "name": "DiceLoss",
#       "params": {}
#     },
#     "scheduler": {
#       "factor": 0.5,
#       "patience": 10
#     },
#     "epochs": 100
#   },
#   "model": {
#     "save_dir": "../../saved_models/isic2018_unet",
#     "load_weights": false,
#     "name": "UNet",
#     "params": {
#       "in_channels": 3,
#       "out_channels": 2,
#       "with_bn": false
#     }
#   }
# }
# ~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-~-

# %% [markdown]
# ## Dataset and Dataloader

# %%
from datasets.isic import ISIC2018DatasetFast
from torch.utils.data import DataLoader, Subset
from torchvision import transforms

# %%
def convert2patches(img,num_parts=4):
    # Dividing each image into 16 equal parts
    num_parts = 4
    part_size = 224 // int(num_parts ** 0.5)  # Size of each part (assuming equal parts)

    # Dividing each image into parts and collecting them in a list
    divided_parts = []
    for i in range(img.shape[0]):
        img_parts = torch.split(img[i], part_size, dim=1)
        for part in img_parts:
            divided_parts.extend(torch.split(part, part_size, dim=2))

    # Creating the final tensor with shape (16*16, 3, part_size, part_size)
    divided_tensor = torch.stack(divided_parts, dim=0)

    # Printing the shape of the divided tensor
    return divided_tensor
def ali(dataloader):
    return dataloader
    # Dividing each image into 16 equal parts
    for sample in dataloader:
        img = sample['image']
        msk = sample['mask']
        sid=samle['id']

        # Printing the shape of the divided tensor
        # print(divided_tensor.shape)
        yield {'image':convert2patches(img),'mask':convert2patches(msk)}

# %%
# ------------------- params --------------------
INPUT_SIZE = config['dataset']['input_size']
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<


# ----------------- dataset --------------------
# preparing training dataset
tr_dataset = ISIC2018DatasetFast(mode="tr", one_hot=True)
vl_dataset = ISIC2018DatasetFast(mode="vl", one_hot=True)
te_dataset = ISIC2018DatasetFast(mode="te", one_hot=True)

# We consider 1815 samples for training, 259 samples for validation and 520 samples for testing
# !cat ~/deeplearning/skin/Prepare_ISIC2018.py

print(f"Length of trainig_dataset:\t{len(tr_dataset)}")
print(f"Length of validation_dataset:\t{len(vl_dataset)}")
print(f"Length of test_dataset:\t\t{len(te_dataset)}")


# prepare train dataloader
tr_dataloader = DataLoader(tr_dataset, **config['data_loader']['train'])

# prepare validation dataloader
vl_dataloader = DataLoader(vl_dataset, **config['data_loader']['validation'])

# prepare test dataloader
te_dataloader = DataLoader(te_dataset, **config['data_loader']['test'])

# -------------- test -----------------
# test and visualize the input data
for sample in tr_dataloader:
    img = sample['image']
    msk = sample['mask']
    print("\n Training")
    show_sbs(img[0], msk[0,1])
    break
    
for sample in vl_dataloader:
    img = sample['image']
    msk = sample['mask']
    print("Validation")
    show_sbs(img[0], msk[0,1])
    break
    
for sample in te_dataloader:
    img = sample['image']
    msk = sample['mask']
    print("Test")
    show_sbs(img[0], msk[0,1])
    break
# Out:
# Length of trainig_dataset:	7260
# Length of validation_dataset:	1036
# Length of test_dataset:		2080
#
#  Training
# Validation
# Test

# %% [markdown]
# ### Device

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Torch device: {device}")
# Out:
# Torch device: cuda

# %% [markdown]
# ## Metrics

# %%
metrics = torchmetrics.MetricCollection(
    [
        torchmetrics.F1Score(),
        torchmetrics.Accuracy(),
        torchmetrics.Dice(),
        torchmetrics.Precision(),
        torchmetrics.Recall(),
        torchmetrics.Specificity(),
        # IoU
        torchmetrics.JaccardIndex(2)
    ],
    prefix='train_metrics/'
)

# train_metrics
train_metrics = metrics.clone(prefix='train_metrics/').to(device)

# valid_metrics
valid_metrics = metrics.clone(prefix='valid_metrics/').to(device)

# test_metrics
test_metrics = metrics.clone(prefix='test_metrics/').to(device)

# %%
def make_serializeable_metrics(computed_metrics):
    res = {}
    for k, v in computed_metrics.items():
        res[k] = float(v.cpu().detach().numpy())
    return res

# %% [markdown]
# ## Define validate function

# %%
def validate(model, criterion, vl_dataloader):
    model.eval()
    with torch.no_grad():
        
        evaluator = valid_metrics.clone().to(device)
        
        losses = []
        cnt = 0.
        for batch, batch_data in enumerate(vl_dataloader):
            imgs = batch_data['image']
            msks = batch_data['mask']
            
            cnt += msks.shape[0]
            
            imgs = imgs.to(device)
            msks = msks.to(device)
            
            preds = model(imgs)
            loss = criterion(preds, msks)
            losses.append(loss.item())
            
            
            preds_ = torch.argmax(preds, 1, keepdim=False).float()
            msks_ = torch.argmax(msks, 1, keepdim=False)
            evaluator.update(preds_, msks_)
        
#             _cml = f"curr_mean-loss:{np.sum(losses)/cnt:0.5f}"
#             _bl = f"batch-loss:{losses[-1]/msks.shape[0]:0.5f}"
#             iterator.set_description(f"Validation) batch:{batch+1:04d} -> {_cml}, {_bl}")
        
        # print the final results
        loss = np.sum(losses)/cnt
        metrics = evaluator.compute()
    
    return evaluator, loss

# %% [markdown]
# ## Define train function

# %%
def train(
    model, 
    device, 
    tr_dataloader,
    vl_dataloader,
    config,
    
    criterion,
    optimizer,
    scheduler,
    
    save_dir='./',
    save_file_id=None,
):
    
    EPOCHS = tr_prms['epochs']
    
    torch.cuda.empty_cache()
    model = model.to(device)

    evaluator = train_metrics.clone().to(device)
    
    epochs_info = []
    best_model = None
    best_result = {}
    best_vl_loss = np.Inf
    for epoch in range(EPOCHS):
        model.train()
        
        evaluator.reset()
        tr_iterator = tqdm(enumerate(tr_dataloader))
        tr_losses = []
        cnt = 0
        for batch, batch_data in tr_iterator:
            imgs = batch_data['image']
            msks = batch_data['mask']
            
            imgs = imgs.to(device)
            msks = msks.to(device)
            
            optimizer.zero_grad()
            preds = model(imgs)
            loss = criterion(preds, msks)
            loss.backward()
            optimizer.step()
            
            # evaluate by metrics
            preds_ = torch.argmax(preds, 1, keepdim=False).float()
            msks_ = torch.argmax(msks, 1, keepdim=False)
            evaluator.update(preds_, msks_)
            
            cnt += imgs.shape[0]
            tr_losses.append(loss.item())
            
            # write details for each training batch
            _cml = f"curr_mean-loss:{np.sum(tr_losses)/cnt:0.5f}"
            _bl = f"mean_batch-loss:{tr_losses[-1]/imgs.shape[0]:0.5f}"
            tr_iterator.set_description(f"Training) ep:{epoch:03d}, batch:{batch+1:04d} -> {_cml}, {_bl}")
            
        tr_loss = np.sum(tr_losses)/cnt
        
        # validate model
        vl_metrics, vl_loss = validate(model, criterion, vl_dataloader)
        if vl_loss < best_vl_loss:
            # find a better model
            best_model = model
            best_vl_loss = vl_loss
            best_result = {
                'tr_loss': tr_loss,
                'vl_loss': vl_loss,
                'tr_metrics': make_serializeable_metrics(evaluator.compute()),
                'vl_metrics': make_serializeable_metrics(vl_metrics.compute())
            }
        
        # write the final results
        epoch_info = {
            'tr_loss': tr_loss,
            'vl_loss': vl_loss,
            'tr_metrics': make_serializeable_metrics(evaluator.compute()),
            'vl_metrics': make_serializeable_metrics(vl_metrics.compute())
        }
        epochs_info.append(epoch_info)
#         epoch_tqdm.set_description(f"Epoch:{epoch+1}/{EPOCHS} -> tr_loss:{tr_loss}, vl_loss:{vl_loss}")
        evaluator.reset()
    
        scheduler.step(vl_loss)
  
    # save final results
    res = {
        'id': save_file_id,
        'config': config,
        'epochs_info': epochs_info,
        'best_result': best_result
    }
    fn = f"{save_file_id+'_' if save_file_id else ''}result.json"
    fp = os.path.join(config['model']['save_dir'],fn)
    with open(fp, "w") as write_file:
        json.dump(res, write_file, indent=4)

    # save model's state_dict
    fn = "last_model_state_dict.pt"
    fp = os.path.join(config['model']['save_dir'],fn)
    torch.save(model.state_dict(), fp)
    
    # save the best model's state_dict
    fn = "best_model_state_dict.pt"
    fp = os.path.join(config['model']['save_dir'], fn)
    torch.save(best_model.state_dict(), fp)
    
    return best_model, model, res

# %% [markdown]
# ## Define test function

# %%
def test(model, te_dataloader):
    model.eval()
    with torch.no_grad():
        evaluator = test_metrics.clone().to(device)            
        for batch_data in tqdm(te_dataloader):
            imgs = batch_data['image']
            msks = batch_data['mask']
            
            imgs = imgs.to(device)
            msks = msks.to(device)
            
            preds = model(imgs)
            
            # evaluate by metrics
            preds_ = torch.argmax(preds, 1, keepdim=False).float()
            msks_ = torch.argmax(msks, 1, keepdim=False)
            evaluator.update(preds_, msks_)
            
    return evaluator

# %% [markdown]
# ## Load and prepare model

# %%
from models.unet import UNet as Net


model = Net(**config['model']['params'])
torch.cuda.empty_cache()
model = model.to(device)
print("Number of parameters:", sum(p.numel() for p in model.parameters() if p.requires_grad))

os.makedirs(config['model']['save_dir'], exist_ok=True)
model_path = f"{config['model']['save_dir']}/model_state_dict.pt"

if config['model']['load_weights']:
    model.load_state_dict(torch.load(model_path))
    print("Loaded pre-trained weights...")
    
    
# criterion_dice = DiceLoss()
criterion_dice = DiceLossWithLogtis()
# criterion_ce  = BCELoss()
criterion_ce  = CrossEntropyLoss()


def criterion(preds, masks):
    c_dice = criterion_dice(preds, masks)
    c_ce = criterion_ce(preds, masks)
    return 0.5*c_dice + 0.5*c_ce

tr_prms = config['training']
optimizer = globals()[tr_prms['optimizer']['name']](model.parameters(), **tr_prms['optimizer']['params'])
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', **tr_prms['scheduler'])
# Out:
# Number of parameters: 487314

# %% [markdown]
# ## Start traning

# %%
best_model, model, res = train(
    model, 
    device, 
    tr_dataloader,
    vl_dataloader,
    config,
    
    criterion,
    optimizer,
    scheduler,

    save_dir = config['model']['save_dir'],
    save_file_id = None,
)
# Out:
# Training) ep:000, batch:0454 -> curr_mean-loss:0.02412, mean_batch-loss:0.02357: : 454it [00:09, 48.54it/s]
# Training) ep:001, batch:0454 -> curr_mean-loss:0.01582, mean_batch-loss:0.04183: : 454it [00:07, 59.52it/s]
# Training) ep:002, batch:0454 -> curr_mean-loss:0.01458, mean_batch-loss:0.02167: : 454it [00:07, 57.54it/s]
# Training) ep:003, batch:0454 -> curr_mean-loss:0.01414, mean_batch-loss:0.01936: : 454it [00:08, 54.19it/s]
# Training) ep:004, batch:0454 -> curr_mean-loss:0.01345, mean_batch-loss:0.02997: : 454it [00:07, 60.35it/s]
# Training) ep:005, batch:0454 -> curr_mean-loss:0.01316, mean_batch-loss:0.01393: : 454it [00:07, 58.14it/s]
# Training) ep:006, batch:0454 -> curr_mean-loss:0.01293, mean_batch-loss:0.01142: : 454it [00:07, 59.04it/s]
# Training) ep:007, batch:0454 -> curr_mean-loss:0.01256, mean_batch-loss:0.01291: : 454it [00:07, 60.99it/s]
# Training) ep:008, batch:0454 -> curr_mean-loss:0.01224, mean_batch-loss:0.01394: : 454it [00:07, 59.46it/s]
# Training) ep:009, batch:0454 -> curr_mean-loss:0.01224, mean_batch-loss:0.02102: : 454it [00:07, 58.60it/s]
# Training) ep:010, batch:0454 -> curr_mean-loss:0.01202, mean_batch-loss:0.02727: : 454it [00:07, 58.28it/s]
# Training) ep:011, batch:0454 -> curr_mean-loss:0.01179, mean_batch-loss:0.01542: : 454it [00:08, 54.89it/s]
# Training) ep:012, batch:0454 -> curr_mean-loss:0.01136, mean_batch-loss:0.01345: : 454it [00:07, 59.13it/s]
# Training) ep:013, batch:0454 -> curr_mean-loss:0.01131, mean_batch-loss:0.01894: : 454it [00:07, 58.06it/s]
# Training) ep:014, batch:0454 -> curr_mean-loss:0.01102, mean_batch-loss:0.02752: : 454it [00:07, 59.23it/s]
# Training) ep:015, batch:0454 -> curr_mean-loss:0.01102, mean_batch-loss:0.01620: : 454it [00:07, 57.02it/s]
# Training) ep:016, batch:0454 -> curr_mean-loss:0.01078, mean_batch-loss:0.01938: : 454it [00:08, 55.92it/s]
# Training) ep:017, batch:0454 -> curr_mean-loss:0.01065, mean_batch-loss:0.02366: : 454it [00:07, 58.00it/s]
# Training) ep:018, batch:0454 -> curr_mean-loss:0.01060, mean_batch-loss:0.01295: : 454it [00:08, 54.72it/s]
# Training) ep:019, batch:0454 -> curr_mean-loss:0.01046, mean_batch-loss:0.00904: : 454it [00:08, 54.12it/s]
# Training) ep:020, batch:0454 -> curr_mean-loss:0.01030, mean_batch-loss:0.01121: : 454it [00:08, 56.15it/s]
# Training) ep:021, batch:0454 -> curr_mean-loss:0.01021, mean_batch-loss:0.01435: : 454it [00:08, 54.04it/s]
# Training) ep:022, batch:0454 -> curr_mean-loss:0.01008, mean_batch-loss:0.00829: : 454it [00:07, 61.91it/s]
# Training) ep:023, batch:0454 -> curr_mean-loss:0.01006, mean_batch-loss:0.01709: : 454it [00:07, 60.53it/s]
# Training) ep:024, batch:0454 -> curr_mean-loss:0.00995, mean_batch-loss:0.01310: : 454it [00:07, 57.15it/s]
# Training) ep:025, batch:0454 -> curr_mean-loss:0.00974, mean_batch-loss:0.00931: : 454it [00:07, 59.86it/s]
# Training) ep:026, batch:0454 -> curr_mean-loss:0.00989, mean_batch-loss:0.00641: : 454it [00:08, 56.67it/s]
# Training) ep:027, batch:0454 -> curr_mean-loss:0.00976, mean_batch-loss:0.01339: : 454it [00:08, 56.44it/s]
# Training) ep:028, batch:0454 -> curr_mean-loss:0.00970, mean_batch-loss:0.01010: : 454it [00:08, 55.59it/s]
# Training) ep:029, batch:0454 -> curr_mean-loss:0.00957, mean_batch-loss:0.01064: : 454it [00:07, 60.93it/s]
# Training) ep:030, batch:0454 -> curr_mean-loss:0.00950, mean_batch-loss:0.01706: : 454it [00:08, 54.23it/s]
# Training) ep:031, batch:0454 -> curr_mean-loss:0.00938, mean_batch-loss:0.01041: : 454it [00:07, 60.62it/s]
# Training) ep:032, batch:0454 -> curr_mean-loss:0.00935, mean_batch-loss:0.01408: : 454it [00:07, 59.40it/s]
# Training) ep:033, batch:0454 -> curr_mean-loss:0.00920, mean_batch-loss:0.00710: : 454it [00:07, 56.84it/s]
# Training) ep:034, batch:0454 -> curr_mean-loss:0.00914, mean_batch-loss:0.01128: : 454it [00:07, 57.56it/s]
# Training) ep:035, batch:0454 -> curr_mean-loss:0.00918, mean_batch-loss:0.01011: : 454it [00:07, 60.81it/s]
# Training) ep:036, batch:0454 -> curr_mean-loss:0.00906, mean_batch-loss:0.01183: : 454it [00:07, 61.10it/s]
# Training) ep:037, batch:0454 -> curr_mean-loss:0.00892, mean_batch-loss:0.01715: : 454it [00:07, 60.57it/s]
# Training) ep:038, batch:0454 -> curr_mean-loss:0.00894, mean_batch-loss:0.01634: : 454it [00:07, 60.26it/s]
# Training) ep:039, batch:0454 -> curr_mean-loss:0.00876, mean_batch-loss:0.00704: : 454it [00:07, 59.32it/s]
# Training) ep:040, batch:0454 -> curr_mean-loss:0.00869, mean_batch-loss:0.00727: : 454it [00:07, 59.94it/s]
# Training) ep:041, batch:0454 -> curr_mean-loss:0.00857, mean_batch-loss:0.00581: : 454it [00:07, 59.47it/s]
# Training) ep:042, batch:0454 -> curr_mean-loss:0.00858, mean_batch-loss:0.00602: : 454it [00:07, 59.50it/s]
# Training) ep:043, batch:0454 -> curr_mean-loss:0.00845, mean_batch-loss:0.01132: : 454it [00:07, 57.38it/s]
# Training) ep:044, batch:0454 -> curr_mean-loss:0.00856, mean_batch-loss:0.00626: : 454it [00:07, 58.65it/s]
# Training) ep:045, batch:0454 -> curr_mean-loss:0.00828, mean_batch-loss:0.00878: : 454it [00:08, 56.24it/s]
# Training) ep:046, batch:0454 -> curr_mean-loss:0.00825, mean_batch-loss:0.02398: : 454it [00:07, 61.26it/s]
# Training) ep:047, batch:0454 -> curr_mean-loss:0.00822, mean_batch-loss:0.00685: : 454it [00:07, 60.44it/s]
# Training) ep:048, batch:0454 -> curr_mean-loss:0.00801, mean_batch-loss:0.01218: : 454it [00:07, 60.41it/s]
# Training) ep:049, batch:0454 -> curr_mean-loss:0.00810, mean_batch-loss:0.01260: : 454it [00:07, 61.03it/s]
# Training) ep:050, batch:0454 -> curr_mean-loss:0.00809, mean_batch-loss:0.01099: : 454it [00:07, 57.28it/s]
# Training) ep:051, batch:0454 -> curr_mean-loss:0.00801, mean_batch-loss:0.01400: : 454it [00:07, 58.46it/s]
# Training) ep:052, batch:0454 -> curr_mean-loss:0.00794, mean_batch-loss:0.01709: : 454it [00:07, 59.24it/s]
# Training) ep:053, batch:0454 -> curr_mean-loss:0.00780, mean_batch-loss:0.01537: : 454it [00:07, 57.68it/s]
# Training) ep:054, batch:0454 -> curr_mean-loss:0.00762, mean_batch-loss:0.00892: : 454it [00:08, 53.39it/s]
# Training) ep:055, batch:0454 -> curr_mean-loss:0.00767, mean_batch-loss:0.01128: : 454it [00:08, 56.22it/s]
# Training) ep:056, batch:0454 -> curr_mean-loss:0.00755, mean_batch-loss:0.00756: : 454it [00:07, 57.10it/s]
# Training) ep:057, batch:0454 -> curr_mean-loss:0.00742, mean_batch-loss:0.01084: : 454it [00:07, 57.66it/s]
# Training) ep:058, batch:0454 -> curr_mean-loss:0.00750, mean_batch-loss:0.00868: : 454it [00:07, 61.34it/s]
# Training) ep:059, batch:0454 -> curr_mean-loss:0.00730, mean_batch-loss:0.00779: : 454it [00:07, 59.57it/s]
# Training) ep:060, batch:0454 -> curr_mean-loss:0.00725, mean_batch-loss:0.01031: : 454it [00:07, 61.94it/s]
# Training) ep:061, batch:0454 -> curr_mean-loss:0.00719, mean_batch-loss:0.00690: : 454it [00:08, 53.78it/s]
# Training) ep:062, batch:0454 -> curr_mean-loss:0.00714, mean_batch-loss:0.00646: : 454it [00:07, 57.89it/s]
# Training) ep:063, batch:0454 -> curr_mean-loss:0.00700, mean_batch-loss:0.02233: : 454it [00:07, 58.10it/s]
# Training) ep:064, batch:0454 -> curr_mean-loss:0.00645, mean_batch-loss:0.00716: : 454it [00:07, 60.07it/s]
# Training) ep:065, batch:0454 -> curr_mean-loss:0.00635, mean_batch-loss:0.00833: : 454it [00:07, 60.38it/s]
# Training) ep:066, batch:0454 -> curr_mean-loss:0.00634, mean_batch-loss:0.01243: : 454it [00:07, 59.03it/s]
# Training) ep:067, batch:0454 -> curr_mean-loss:0.00618, mean_batch-loss:0.01742: : 454it [00:07, 59.81it/s]
# Training) ep:068, batch:0454 -> curr_mean-loss:0.00618, mean_batch-loss:0.00580: : 454it [00:07, 58.18it/s]
# Training) ep:069, batch:0454 -> curr_mean-loss:0.00609, mean_batch-loss:0.00965: : 454it [00:07, 59.01it/s]
# Training) ep:070, batch:0454 -> curr_mean-loss:0.00602, mean_batch-loss:0.00876: : 454it [00:07, 59.53it/s]
# Training) ep:071, batch:0454 -> curr_mean-loss:0.00601, mean_batch-loss:0.00312: : 454it [00:08, 52.66it/s]
# Training) ep:072, batch:0454 -> curr_mean-loss:0.00590, mean_batch-loss:0.00922: : 454it [00:08, 55.54it/s]
# Training) ep:073, batch:0454 -> curr_mean-loss:0.00585, mean_batch-loss:0.00539: : 454it [00:08, 54.01it/s]
# Training) ep:074, batch:0454 -> curr_mean-loss:0.00584, mean_batch-loss:0.01572: : 454it [00:07, 60.15it/s]
# Training) ep:075, batch:0454 -> curr_mean-loss:0.00548, mean_batch-loss:0.00470: : 454it [00:07, 60.76it/s]
# Training) ep:076, batch:0454 -> curr_mean-loss:0.00543, mean_batch-loss:0.01103: : 454it [00:07, 61.14it/s]
# Training) ep:077, batch:0454 -> curr_mean-loss:0.00539, mean_batch-loss:0.01647: : 454it [00:07, 58.58it/s]
# Training) ep:078, batch:0454 -> curr_mean-loss:0.00537, mean_batch-loss:0.00688: : 454it [00:07, 58.75it/s]
# Training) ep:079, batch:0454 -> curr_mean-loss:0.00529, mean_batch-loss:0.00366: : 454it [00:07, 58.68it/s]
# Training) ep:080, batch:0454 -> curr_mean-loss:0.00526, mean_batch-loss:0.00632: : 454it [00:07, 61.26it/s]
# Training) ep:081, batch:0454 -> curr_mean-loss:0.00522, mean_batch-loss:0.00937: : 454it [00:07, 57.39it/s]
# Training) ep:082, batch:0454 -> curr_mean-loss:0.00517, mean_batch-loss:0.00302: : 454it [00:07, 61.22it/s]
# Training) ep:083, batch:0454 -> curr_mean-loss:0.00516, mean_batch-loss:0.00503: : 454it [00:07, 61.72it/s]
# Training) ep:084, batch:0454 -> curr_mean-loss:0.00514, mean_batch-loss:0.00605: : 454it [00:07, 58.62it/s]
# Training) ep:085, batch:0454 -> curr_mean-loss:0.00509, mean_batch-loss:0.00834: : 454it [00:08, 55.35it/s]
# Training) ep:086, batch:0454 -> curr_mean-loss:0.00491, mean_batch-loss:0.00688: : 454it [00:07, 57.87it/s]
# Training) ep:087, batch:0454 -> curr_mean-loss:0.00487, mean_batch-loss:0.00396: : 454it [00:07, 60.99it/s]
# Training) ep:088, batch:0454 -> curr_mean-loss:0.00486, mean_batch-loss:0.00619: : 454it [00:07, 60.43it/s]
# Training) ep:089, batch:0454 -> curr_mean-loss:0.00482, mean_batch-loss:0.00446: : 454it [00:07, 60.66it/s]
# Training) ep:090, batch:0454 -> curr_mean-loss:0.00482, mean_batch-loss:0.00375: : 454it [00:08, 53.90it/s]
# Training) ep:091, batch:0454 -> curr_mean-loss:0.00478, mean_batch-loss:0.00833: : 454it [00:07, 61.44it/s]
# Training) ep:092, batch:0454 -> curr_mean-loss:0.00478, mean_batch-loss:0.00394: : 454it [00:07, 58.83it/s]
# Training) ep:093, batch:0454 -> curr_mean-loss:0.00474, mean_batch-loss:0.00662: : 454it [00:07, 59.62it/s]
# Training) ep:094, batch:0454 -> curr_mean-loss:0.00472, mean_batch-loss:0.00381: : 454it [00:07, 57.26it/s]
# Training) ep:095, batch:0454 -> curr_mean-loss:0.00471, mean_batch-loss:0.01158: : 454it [00:07, 59.73it/s]
# Training) ep:096, batch:0454 -> curr_mean-loss:0.00466, mean_batch-loss:0.00642: : 454it [00:08, 55.38it/s]
# Training) ep:097, batch:0454 -> curr_mean-loss:0.00459, mean_batch-loss:0.00417: : 454it [00:07, 57.24it/s]
# Training) ep:098, batch:0454 -> curr_mean-loss:0.00456, mean_batch-loss:0.00457: : 454it [00:08, 55.29it/s]
# Training) ep:099, batch:0454 -> curr_mean-loss:0.00455, mean_batch-loss:0.00287: : 454it [00:07, 59.32it/s]

# %%
te_metrics = test(best_model, te_dataloader)
te_metrics.compute()
# Out:
# 100%|██████████| 130/130 [00:01<00:00, 93.21it/s]
# {'test_metrics/F1Score': tensor(0.8329, device='cuda:0'),
#  'test_metrics/Accuracy': tensor(0.9289, device='cuda:0'),
#  'test_metrics/Dice': tensor(0.8329, device='cuda:0'),
#  'test_metrics/Precision': tensor(0.8522, device='cuda:0'),
#  'test_metrics/Recall': tensor(0.8144, device='cuda:0'),
#  'test_metrics/Specificity': tensor(0.9607, device='cuda:0'),
#  'test_metrics/JaccardIndex': tensor(0.8136, device='cuda:0')}

# %%
f"{config['model']['save_dir']}"
# Out:
# '../../saved_models/isic2018_unet'

# %% [markdown]
# # Test the best inferred model
# ----

# %% [markdown]
# ## Load the best model

# %%
best_model = Net(**config['model']['params'])
torch.cuda.empty_cache()
best_model = best_model.to(device)

fn = "best_model_state_dict.pt"
os.makedirs(config['model']['save_dir'], exist_ok=True)
model_path = f"{config['model']['save_dir']}/{fn}"

best_model.load_state_dict(torch.load(model_path))
print("Loaded best model weights...")
# Out:
# Loaded best model weights...

# %% [markdown]
# ## Evaluation

# %%
te_metrics = test(best_model, te_dataloader)
te_metrics.compute()
# Out:
# 100%|██████████| 130/130 [00:01<00:00, 93.59it/s]
# {'test_metrics/F1Score': tensor(0.8329, device='cuda:0'),
#  'test_metrics/Accuracy': tensor(0.9289, device='cuda:0'),
#  'test_metrics/Dice': tensor(0.8329, device='cuda:0'),
#  'test_metrics/Precision': tensor(0.8522, device='cuda:0'),
#  'test_metrics/Recall': tensor(0.8144, device='cuda:0'),
#  'test_metrics/Specificity': tensor(0.9607, device='cuda:0'),
#  'test_metrics/JaccardIndex': tensor(0.8136, device='cuda:0')}

# %% [markdown]
# ## Plot graphs

# %%
result_file_path = f"{config['model']['save_dir']}/result.json"
with open(result_file_path, 'r') as f:
    results = json.loads(''.join(f.readlines()))
epochs_info = results['epochs_info']

tr_losses = [d['tr_loss'] for d in epochs_info]
vl_losses = [d['vl_loss'] for d in epochs_info]
tr_dice = [d['tr_metrics']['train_metrics/Dice'] for d in epochs_info]
vl_dice = [d['vl_metrics']['valid_metrics/Dice'] for d in epochs_info]
tr_js = [d['tr_metrics']['train_metrics/JaccardIndex'] for d in epochs_info]
vl_js = [d['vl_metrics']['valid_metrics/JaccardIndex'] for d in epochs_info]
tr_acc = [d['tr_metrics']['train_metrics/Accuracy'] for d in epochs_info]
vl_acc = [d['vl_metrics']['valid_metrics/Accuracy'] for d in epochs_info]


_, axs = plt.subplots(1, 4, figsize=[16,3])

axs[0].set_title("Loss")
axs[0].plot(tr_losses, 'r-', label="train loss")
axs[0].plot(vl_losses, 'b-', label="validatiton loss")
axs[0].legend()

axs[1].set_title("Dice score")
axs[1].plot(tr_dice, 'r-', label="train dice")
axs[1].plot(vl_dice, 'b-', label="validation dice")
axs[1].legend()

axs[2].set_title("Jaccard Similarity")
axs[2].plot(tr_js, 'r-', label="train JaccardIndex")
axs[2].plot(vl_js, 'b-', label="validatiton JaccardIndex")
axs[2].legend()

axs[3].set_title("Accuracy")
axs[3].plot(tr_acc, 'r-', label="train Accuracy")
axs[3].plot(vl_acc, 'b-', label="validation Accuracy")
axs[3].legend()

plt.show()

# %%
epochs_info
# Out:
# [{'tr_loss': 0.024115483232930345,
#   'vl_loss': 0.016968056120870195,
#   'tr_metrics': {'train_metrics/F1Score': 0.4784017503261566,
#    'train_metrics/Accuracy': 0.8374636173248291,
#    'train_metrics/Dice': 0.47840172052383423,
#    'train_metrics/Precision': 0.7396436333656311,
#    'train_metrics/Recall': 0.35353371500968933,
#    'train_metrics/Specificity': 0.9667527675628662,
#    'train_metrics/JaccardIndex': 0.569390058517456},
#   'vl_metrics': {'valid_metrics/F1Score': 0.7304774522781372,
#    'valid_metrics/Accuracy': 0.8879957795143127,
#    'valid_metrics/Dice': 0.730477511882782,
#    'valid_metrics/Precision': 0.8143705129623413,
#    'valid_metrics/Recall': 0.662254810333252,
#    'valid_metrics/Specificity': 0.9551159143447876,
#    'valid_metrics/JaccardIndex': 0.7216745615005493}},
#  {'tr_loss': 0.01581671410150436,
#   'vl_loss': 0.015273346108992128,
#   'tr_metrics': {'train_metrics/F1Score': 0.7386414408683777,
#    'train_metrics/Accuracy': 0.8948124647140503,
#    'train_metrics/Dice': 0.7386413812637329,
#    'train_metrics/Precision': 0.7756627798080444,
#    'train_metrics/Recall': 0.7049930691719055,
#    'train_metrics/Specificity': 0.9455256462097168,
#    'train_metrics/JaccardIndex': 0.7310199737548828},
#   'vl_metrics': {'valid_metrics/F1Score': 0.7535297274589539,
#    'valid_metrics/Accuracy': 0.8970737457275391,
#    'valid_metrics/Dice': 0.7535297274589539,
#    'valid_metrics/Precision': 0.8350641131401062,
#    'valid_metrics/Recall': 0.6865008473396301,
#    'valid_metrics/Specificity': 0.959683895111084,
#    'valid_metrics/JaccardIndex': 0.741193413734436}},
#  {'tr_loss': 0.014581581896822644,
#   'vl_loss': 0.014052033834303208,
#   'tr_metrics': {'train_metrics/F1Score': 0.7563583850860596,
#    'train_metrics/Accuracy': 0.9017921090126038,
#    'train_metrics/Dice': 0.7563583254814148,
#    'train_metrics/Precision': 0.7929282784461975,
#    'train_metrics/Recall': 0.7230129837989807,
#    'train_metrics/Specificity': 0.9495556354522705,
#    'train_metrics/JaccardIndex': 0.7461546659469604},
#   'vl_metrics': {'valid_metrics/F1Score': 0.7779097557067871,
#    'valid_metrics/Accuracy': 0.9000449776649475,
#    'valid_metrics/Dice': 0.7779098153114319,
#    'valid_metrics/Precision': 0.7925434112548828,
#    'valid_metrics/Recall': 0.7638067603111267,
#    'valid_metrics/Specificity': 0.9405530095100403,
#    'valid_metrics/JaccardIndex': 0.7576873302459717}},
#  {'tr_loss': 0.014137209259158323,
#   'vl_loss': 0.013731913914379005,
#   'tr_metrics': {'train_metrics/F1Score': 0.7642039656639099,
#    'train_metrics/Accuracy': 0.9048416018486023,
#    'train_metrics/Dice': 0.7642039060592651,
#    'train_metrics/Precision': 0.8001114726066589,
#    'train_metrics/Recall': 0.7313809990882874,
#    'train_metrics/Specificity': 0.9511841535568237,
#    'train_metrics/JaccardIndex': 0.752941370010376},
#   'vl_metrics': {'valid_metrics/F1Score': 0.7752584218978882,
#    'valid_metrics/Accuracy': 0.9033229351043701,
#    'valid_metrics/Dice': 0.7752584218978882,
#    'valid_metrics/Precision': 0.8296570181846619,
#    'valid_metrics/Recall': 0.727554440498352,
#    'valid_metrics/Specificity': 0.9555845856666565,
#    'valid_metrics/JaccardIndex': 0.7584869861602783}},
#  {'tr_loss': 0.013447019909367417,
#   'vl_loss': 0.013121193735123141,
#   'tr_metrics': {'train_metrics/F1Score': 0.7723387479782104,
#    'train_metrics/Accuracy': 0.908129096031189,
#    'train_metrics/Dice': 0.7723386883735657,
#    'train_metrics/Precision': 0.8086728453636169,
#    'train_metrics/Recall': 0.739129364490509,
#    'train_metrics/Specificity': 0.953279972076416,
#    'train_metrics/JaccardIndex': 0.7601416707038879},
#   'vl_metrics': {'valid_metrics/F1Score': 0.7827017903327942,
#    'valid_metrics/Accuracy': 0.9057076573371887,
#    'valid_metrics/Dice': 0.7827017307281494,
#    'valid_metrics/Precision': 0.8294258117675781,
#    'valid_metrics/Recall': 0.7409611940383911,
#    'valid_metrics/Specificity': 0.9546921253204346,
#    'valid_metrics/JaccardIndex': 0.7647011280059814}},
#  {'tr_loss': 0.013156969609257276,
#   'vl_loss': 0.012824164387054426,
#   'tr_metrics': {'train_metrics/F1Score': 0.7775405645370483,
#    'train_metrics/Accuracy': 0.9105635285377502,
#    'train_metrics/Dice': 0.7775405645370483,
#    'train_metrics/Precision': 0.8174727559089661,
#    'train_metrics/Recall': 0.7413279414176941,
#    'train_metrics/Specificity': 0.9557774066925049,
#    'train_metrics/JaccardIndex': 0.7650206089019775},
#   'vl_metrics': {'valid_metrics/F1Score': 0.791510820388794,
#    'valid_metrics/Accuracy': 0.9074563980102539,
#    'valid_metrics/Dice': 0.791510820388794,
#    'valid_metrics/Precision': 0.8182359337806702,
#    'valid_metrics/Recall': 0.7664763331413269,
#    'valid_metrics/Specificity': 0.9493743777275085,
#    'valid_metrics/JaccardIndex': 0.7713471055030823}},
#  {'tr_loss': 0.012927005071572692,
#   'vl_loss': 0.012801720483883007,
#   'tr_metrics': {'train_metrics/F1Score': 0.7806199789047241,
#    'train_metrics/Accuracy': 0.9115782380104065,
#    'train_metrics/Dice': 0.7806198596954346,
#    'train_metrics/Precision': 0.8184310793876648,
#    'train_metrics/Recall': 0.7461482286453247,
#    'train_metrics/Specificity': 0.9557754397392273,
#    'train_metrics/JaccardIndex': 0.7676244974136353},
#   'vl_metrics': {'valid_metrics/F1Score': 0.797668993473053,
#    'valid_metrics/Accuracy': 0.9091159105300903,
#    'valid_metrics/Dice': 0.797668993473053,
#    'valid_metrics/Precision': 0.8143293261528015,
#    'valid_metrics/Recall': 0.7816766500473022,
#    'valid_metrics/Specificity': 0.9470077157020569,
#    'valid_metrics/JaccardIndex': 0.776357889175415}},
#  {'tr_loss': 0.01256388664943456,
#   'vl_loss': 0.012858430290429289,
#   'tr_metrics': {'train_metrics/F1Score': 0.7864876985549927,
#    'train_metrics/Accuracy': 0.9139158129692078,
#    'train_metrics/Dice': 0.7864876389503479,
#    'train_metrics/Precision': 0.8242945075035095,
#    'train_metrics/Recall': 0.7519968152046204,
#    'train_metrics/Specificity': 0.9571748971939087,
#    'train_metrics/JaccardIndex': 0.7729020118713379},
#   'vl_metrics': {'valid_metrics/F1Score': 0.7787360548973083,
#    'valid_metrics/Accuracy': 0.9083873629570007,
#    'valid_metrics/Dice': 0.7787361145019531,
#    'valid_metrics/Precision': 0.8721157908439636,
#    'valid_metrics/Recall': 0.7034192085266113,
#    'valid_metrics/Specificity': 0.9693310260772705,
#    'valid_metrics/JaccardIndex': 0.764213502407074}},
#  {'tr_loss': 0.01223900934511965,
#   'vl_loss': 0.013163814364310397,
#   'tr_metrics': {'train_metrics/F1Score': 0.791596531867981,
#    'train_metrics/Accuracy': 0.915713906288147,
#    'train_metrics/Dice': 0.791596531867981,
#    'train_metrics/Precision': 0.8268350958824158,
#    'train_metrics/Recall': 0.7592387795448303,
#    'train_metrics/Specificity': 0.9575186371803284,
#    'train_metrics/JaccardIndex': 0.7773633599281311},
#   'vl_metrics': {'valid_metrics/F1Score': 0.7818460464477539,
#    'valid_metrics/Accuracy': 0.9092645645141602,
#    'valid_metrics/Dice': 0.7818460464477539,
#    'valid_metrics/Precision': 0.8707154393196106,
#    'valid_metrics/Recall': 0.7094374895095825,
#    'valid_metrics/Specificity': 0.968679666519165,
#    'valid_metrics/JaccardIndex': 0.7667378187179565}},
#  {'tr_loss': 0.012237652784249342,
#   'vl_loss': 0.01214566283129357,
#   'tr_metrics': {'train_metrics/F1Score': 0.7928106784820557,
#    'train_metrics/Accuracy': 0.9162309765815735,
#    'train_metrics/Dice': 0.7928106784820557,
#    'train_metrics/Precision': 0.8283836841583252,
#    'train_metrics/Recall': 0.7601670026779175,
#    'train_metrics/Specificity': 0.9579257965087891,
#    'train_metrics/JaccardIndex': 0.7784918546676636},
#   'vl_metrics': {'valid_metrics/F1Score': 0.7986350059509277,
#    'valid_metrics/Accuracy': 0.9129652976989746,
#    'valid_metrics/Dice': 0.7986350059509277,
#    'valid_metrics/Precision': 0.8500677943229675,
#    'valid_metrics/Recall': 0.7530708909034729,
#    'valid_metrics/Specificity': 0.9605070352554321,
#    'valid_metrics/JaccardIndex': 0.779791533946991}},
#  {'tr_loss': 0.012020418294205153,
#   'vl_loss': 0.011934191290591215,
#   'tr_metrics': {'train_metrics/F1Score': 0.7958752512931824,
#    'train_metrics/Accuracy': 0.9177437424659729,
#    'train_metrics/Dice': 0.7958751916885376,
#    'train_metrics/Precision': 0.8346121907234192,
#    'train_metrics/Recall': 0.7605746388435364,
#    'train_metrics/Specificity': 0.9597339034080505,
#    'train_metrics/JaccardIndex': 0.7814958095550537},
#   'vl_metrics': {'valid_metrics/F1Score': 0.801900327205658,
#    'valid_metrics/Accuracy': 0.9153279066085815,
#    'valid_metrics/Dice': 0.801900327205658,
#    'valid_metrics/Precision': 0.864507257938385,
#    'valid_metrics/Recall': 0.7477489709854126,
#    'valid_metrics/Specificity': 0.9651545882225037,
#    'valid_metrics/JaccardIndex': 0.7835631966590881}},
#  {'tr_loss': 0.011787286349482444,
#   'vl_loss': 0.012068833796213953,
#   'tr_metrics': {'train_metrics/F1Score': 0.801694929599762,
#    'train_metrics/Accuracy': 0.9200842976570129,
#    'train_metrics/Dice': 0.8016948699951172,
#    'train_metrics/Precision': 0.8406617641448975,
#    'train_metrics/Recall': 0.7661804556846619,
#    'train_metrics/Specificity': 0.9612020254135132,
#    'train_metrics/JaccardIndex': 0.7868557572364807},
#   'vl_metrics': {'valid_metrics/F1Score': 0.79752117395401,
#    'valid_metrics/Accuracy': 0.9151060581207275,
#    'valid_metrics/Dice': 0.79752117395401,
#    'valid_metrics/Precision': 0.8795493245124817,
#    'valid_metrics/Recall': 0.7294880151748657,
#    'valid_metrics/Specificity': 0.9702963829040527,
#    'valid_metrics/JaccardIndex': 0.7806471586227417}},
#  {'tr_loss': 0.011361331350013572,
#   'vl_loss': 0.012428701621512649,
#   'tr_metrics': {'train_metrics/F1Score': 0.8073133826255798,
#    'train_metrics/Accuracy': 0.9223092198371887,
#    'train_metrics/Dice': 0.8073134422302246,
#    'train_metrics/Precision': 0.8460835218429565,
#    'train_metrics/Recall': 0.7719407677650452,
#    'train_metrics/Specificity': 0.9624824523925781,
#    'train_metrics/JaccardIndex': 0.7920466661453247},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8063599467277527,
#    'valid_metrics/Accuracy': 0.9128189086914062,
#    'valid_metrics/Dice': 0.8063599467277527,
#    'valid_metrics/Precision': 0.821230947971344,
#    'valid_metrics/Recall': 0.7920179963111877,
#    'valid_metrics/Specificity': 0.9487369656562805,
#    'valid_metrics/JaccardIndex': 0.7845155000686646}},
#  {'tr_loss': 0.011307520580480578,
#   'vl_loss': 0.012613303261776688,
#   'tr_metrics': {'train_metrics/F1Score': 0.8086783289909363,
#    'train_metrics/Accuracy': 0.9228418469429016,
#    'train_metrics/Dice': 0.8086783289909363,
#    'train_metrics/Precision': 0.8473016023635864,
#    'train_metrics/Recall': 0.7734227180480957,
#    'train_metrics/Specificity': 0.9627615213394165,
#    'train_metrics/JaccardIndex': 0.7933081388473511},
#   'vl_metrics': {'valid_metrics/F1Score': 0.7858715653419495,
#    'valid_metrics/Accuracy': 0.9111506938934326,
#    'valid_metrics/Dice': 0.7858715057373047,
#    'valid_metrics/Precision': 0.8777667284011841,
#    'valid_metrics/Recall': 0.711394190788269,
#    'valid_metrics/Specificity': 0.9705447554588318,
#    'valid_metrics/JaccardIndex': 0.7705572843551636}},
#  {'tr_loss': 0.011015636014133775,
#   'vl_loss': 0.01189895164811243,
#   'tr_metrics': {'train_metrics/F1Score': 0.8137614727020264,
#    'train_metrics/Accuracy': 0.9247686862945557,
#    'train_metrics/Dice': 0.8137615323066711,
#    'train_metrics/Precision': 0.851100742816925,
#    'train_metrics/Recall': 0.7795608639717102,
#    'train_metrics/Specificity': 0.9635632038116455,
#    'train_metrics/JaccardIndex': 0.797986626625061},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8021571040153503,
#    'valid_metrics/Accuracy': 0.9174790382385254,
#    'valid_metrics/Dice': 0.8021571636199951,
#    'valid_metrics/Precision': 0.8902451395988464,
#    'valid_metrics/Recall': 0.7299318313598633,
#    'valid_metrics/Specificity': 0.9732429385185242,
#    'valid_metrics/JaccardIndex': 0.7852843403816223}},
#  {'tr_loss': 0.01102153133939613,
#   'vl_loss': 0.011574511455810668,
#   'tr_metrics': {'train_metrics/F1Score': 0.8134859204292297,
#    'train_metrics/Accuracy': 0.9246987104415894,
#    'train_metrics/Dice': 0.813485860824585,
#    'train_metrics/Precision': 0.8513231873512268,
#    'train_metrics/Recall': 0.7788688540458679,
#    'train_metrics/Specificity': 0.9636593461036682,
#    'train_metrics/JaccardIndex': 0.7977567315101624},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8196229934692383,
#    'valid_metrics/Accuracy': 0.9177384376525879,
#    'valid_metrics/Dice': 0.8196230530738831,
#    'valid_metrics/Precision': 0.8238165974617004,
#    'valid_metrics/Recall': 0.8154720067977905,
#    'valid_metrics/Specificity': 0.9481455683708191,
#    'valid_metrics/JaccardIndex': 0.7966021299362183}},
#  {'tr_loss': 0.01077926427936669,
#   'vl_loss': 0.01198008148769154,
#   'tr_metrics': {'train_metrics/F1Score': 0.8190228343009949,
#    'train_metrics/Accuracy': 0.9268376231193542,
#    'train_metrics/Dice': 0.8190228343009949,
#    'train_metrics/Precision': 0.8558833599090576,
#    'train_metrics/Recall': 0.785206139087677,
#    'train_metrics/Specificity': 0.9646766781806946,
#    'train_metrics/JaccardIndex': 0.8029177188873291},
#   'vl_metrics': {'valid_metrics/F1Score': 0.7955975532531738,
#    'valid_metrics/Accuracy': 0.9165825843811035,
#    'valid_metrics/Dice': 0.7955976128578186,
#    'valid_metrics/Precision': 0.9073696136474609,
#    'valid_metrics/Recall': 0.7083422541618347,
#    'valid_metrics/Specificity': 0.978499174118042,
#    'valid_metrics/JaccardIndex': 0.7804951667785645}},
#  {'tr_loss': 0.010653436547735342,
#   'vl_loss': 0.012358567350216815,
#   'tr_metrics': {'train_metrics/F1Score': 0.8210662603378296,
#    'train_metrics/Accuracy': 0.9275701642036438,
#    'train_metrics/Dice': 0.8210662603378296,
#    'train_metrics/Precision': 0.8568132519721985,
#    'train_metrics/Recall': 0.7881826758384705,
#    'train_metrics/Specificity': 0.9648097157478333,
#    'train_metrics/JaccardIndex': 0.8047916889190674},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8123632669448853,
#    'valid_metrics/Accuracy': 0.9085857272148132,
#    'valid_metrics/Dice': 0.81236332654953,
#    'valid_metrics/Precision': 0.7670023441314697,
#    'valid_metrics/Recall': 0.8634268641471863,
#    'valid_metrics/Specificity': 0.9220129251480103,
#    'valid_metrics/JaccardIndex': 0.785024881362915}},
#  {'tr_loss': 0.01059963436227692,
#   'vl_loss': 0.011107285970886702,
#   'tr_metrics': {'train_metrics/F1Score': 0.8218392133712769,
#    'train_metrics/Accuracy': 0.9278697967529297,
#    'train_metrics/Dice': 0.8218392133712769,
#    'train_metrics/Precision': 0.8574483394622803,
#    'train_metrics/Recall': 0.7890698313713074,
#    'train_metrics/Specificity': 0.9649524092674255,
#    'train_metrics/JaccardIndex': 0.8055181503295898},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8176953196525574,
#    'valid_metrics/Accuracy': 0.9209752082824707,
#    'valid_metrics/Dice': 0.8176952600479126,
#    'valid_metrics/Precision': 0.8675258755683899,
#    'valid_metrics/Recall': 0.7732782363891602,
#    'valid_metrics/Specificity': 0.9648903608322144,
#    'valid_metrics/JaccardIndex': 0.797782301902771}},
#  {'tr_loss': 0.010464336707695457,
#   'vl_loss': 0.011187400920568285,
#   'tr_metrics': {'train_metrics/F1Score': 0.8242540955543518,
#    'train_metrics/Accuracy': 0.928750216960907,
#    'train_metrics/Dice': 0.824254035949707,
#    'train_metrics/Precision': 0.8586938977241516,
#    'train_metrics/Recall': 0.792470395565033,
#    'train_metrics/Specificity': 0.9651594161987305,
#    'train_metrics/JaccardIndex': 0.8077527284622192},
#   'vl_metrics': {'valid_metrics/F1Score': 0.821968674659729,
#    'valid_metrics/Accuracy': 0.9193404316902161,
#    'valid_metrics/Dice': 0.8219686150550842,
#    'valid_metrics/Precision': 0.8317190408706665,
#    'valid_metrics/Recall': 0.8124442100524902,
#    'valid_metrics/Specificity': 0.9511241316795349,
#    'valid_metrics/JaccardIndex': 0.79931640625}},
#  {'tr_loss': 0.010295973138334667,
#   'vl_loss': 0.0114522926854581,
#   'tr_metrics': {'train_metrics/F1Score': 0.8269885778427124,
#    'train_metrics/Accuracy': 0.9298595190048218,
#    'train_metrics/Dice': 0.8269885182380676,
#    'train_metrics/Precision': 0.8615515828132629,
#    'train_metrics/Recall': 0.7950916886329651,
#    'train_metrics/Specificity': 0.9658647179603577,
#    'train_metrics/JaccardIndex': 0.8103733062744141},
#   'vl_metrics': {'valid_metrics/F1Score': 0.811654269695282,
#    'valid_metrics/Accuracy': 0.9201813340187073,
#    'valid_metrics/Dice': 0.811654269695282,
#    'valid_metrics/Precision': 0.8837835788726807,
#    'valid_metrics/Recall': 0.7504101395606995,
#    'valid_metrics/Specificity': 0.9706598520278931,
#    'valid_metrics/JaccardIndex': 0.7933071851730347}},
#  {'tr_loss': 0.010212729008196142,
#   'vl_loss': 0.010923521010686991,
#   'tr_metrics': {'train_metrics/F1Score': 0.8288372755050659,
#    'train_metrics/Accuracy': 0.9306203126907349,
#    'train_metrics/Dice': 0.8288373351097107,
#    'train_metrics/Precision': 0.8636307716369629,
#    'train_metrics/Recall': 0.7967388033866882,
#    'train_metrics/Specificity': 0.9663888812065125,
#    'train_metrics/JaccardIndex': 0.8121587634086609},
#   'vl_metrics': {'valid_metrics/F1Score': 0.825803816318512,
#    'valid_metrics/Accuracy': 0.9224866032600403,
#    'valid_metrics/Dice': 0.8258037567138672,
#    'valid_metrics/Precision': 0.851439356803894,
#    'valid_metrics/Recall': 0.8016667366027832,
#    'valid_metrics/Specificity': 0.9584102630615234,
#    'valid_metrics/JaccardIndex': 0.8041660189628601}},
#  {'tr_loss': 0.010084741944370191,
#   'vl_loss': 0.010900845405965698,
#   'tr_metrics': {'train_metrics/F1Score': 0.8312103748321533,
#    'train_metrics/Accuracy': 0.9315124750137329,
#    'train_metrics/Dice': 0.831210196018219,
#    'train_metrics/Precision': 0.8651490211486816,
#    'train_metrics/Recall': 0.7998338341712952,
#    'train_metrics/Specificity': 0.9666924476623535,
#    'train_metrics/JaccardIndex': 0.8143961429595947},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8287963271141052,
#    'valid_metrics/Accuracy': 0.9227287769317627,
#    'valid_metrics/Dice': 0.8287962675094604,
#    'valid_metrics/Precision': 0.8419175744056702,
#    'valid_metrics/Recall': 0.816077709197998,
#    'valid_metrics/Specificity': 0.9544395804405212,
#    'valid_metrics/JaccardIndex': 0.8062980771064758}},
#  {'tr_loss': 0.010055438623591723,
#   'vl_loss': 0.011111621561542901,
#   'tr_metrics': {'train_metrics/F1Score': 0.8314714431762695,
#    'train_metrics/Accuracy': 0.9316132664680481,
#    'train_metrics/Dice': 0.8314714431762695,
#    'train_metrics/Precision': 0.8653489351272583,
#    'train_metrics/Recall': 0.8001465797424316,
#    'train_metrics/Specificity': 0.9667365550994873,
#    'train_metrics/JaccardIndex': 0.8146446943283081},
#   'vl_metrics': {'valid_metrics/F1Score': 0.829289972782135,
#    'valid_metrics/Accuracy': 0.9208102822303772,
#    'valid_metrics/Dice': 0.8292899131774902,
#    'valid_metrics/Precision': 0.8195564150810242,
#    'valid_metrics/Recall': 0.8392573595046997,
#    'valid_metrics/Specificity': 0.9450585842132568,
#    'valid_metrics/JaccardIndex': 0.8051577806472778}},
#  {'tr_loss': 0.009946874819552275,
#   'vl_loss': 0.010731467088993682,
#   'tr_metrics': {'train_metrics/F1Score': 0.8334382176399231,
#    'train_metrics/Accuracy': 0.9323743581771851,
#    'train_metrics/Dice': 0.8334381580352783,
#    'train_metrics/Precision': 0.8668830990791321,
#    'train_metrics/Recall': 0.8024780750274658,
#    'train_metrics/Specificity': 0.9670780301094055,
#    'train_metrics/JaccardIndex': 0.8165210485458374},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8286067843437195,
#    'valid_metrics/Accuracy': 0.9231973886489868,
#    'valid_metrics/Dice': 0.8286068439483643,
#    'valid_metrics/Precision': 0.8480374217033386,
#    'valid_metrics/Recall': 0.8100466728210449,
#    'valid_metrics/Specificity': 0.9568407535552979,
#    'valid_metrics/JaccardIndex': 0.8065283894538879}},
#  {'tr_loss': 0.009740993584770473,
#   'vl_loss': 0.01047328084304526,
#   'tr_metrics': {'train_metrics/F1Score': 0.8369630575180054,
#    'train_metrics/Accuracy': 0.9337852001190186,
#    'train_metrics/Dice': 0.8369629979133606,
#    'train_metrics/Precision': 0.8702623844146729,
#    'train_metrics/Recall': 0.8061181902885437,
#    'train_metrics/Specificity': 0.9678934216499329,
#    'train_metrics/JaccardIndex': 0.8199313879013062},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8312802314758301,
#    'valid_metrics/Accuracy': 0.92583167552948,
#    'valid_metrics/Dice': 0.8312802910804749,
#    'valid_metrics/Precision': 0.8683784008026123,
#    'valid_metrics/Recall': 0.7972220778465271,
#    'valid_metrics/Specificity': 0.9640714526176453,
#    'valid_metrics/JaccardIndex': 0.8102624416351318}},
#  {'tr_loss': 0.009887362129924712,
#   'vl_loss': 0.011439501095750157,
#   'tr_metrics': {'train_metrics/F1Score': 0.8343192338943481,
#    'train_metrics/Accuracy': 0.9326684474945068,
#    'train_metrics/Dice': 0.8343191146850586,
#    'train_metrics/Precision': 0.8669156432151794,
#    'train_metrics/Recall': 0.8040851950645447,
#    'train_metrics/Specificity': 0.9670215249061584,
#    'train_metrics/JaccardIndex': 0.8173295259475708},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8111024498939514,
#    'valid_metrics/Accuracy': 0.9189699292182922,
#    'valid_metrics/Dice': 0.8111025094985962,
#    'valid_metrics/Precision': 0.8708096742630005,
#    'valid_metrics/Recall': 0.7590576410293579,
#    'valid_metrics/Specificity': 0.9665170311927795,
#    'valid_metrics/JaccardIndex': 0.7920677661895752}},
#  {'tr_loss': 0.00975848729350186,
#   'vl_loss': 0.010807671188646532,
#   'tr_metrics': {'train_metrics/F1Score': 0.8370863795280457,
#    'train_metrics/Accuracy': 0.9338229894638062,
#    'train_metrics/Dice': 0.8370863795280457,
#    'train_metrics/Precision': 0.8702152967453003,
#    'train_metrics/Recall': 0.8063874244689941,
#    'train_metrics/Specificity': 0.9678694009780884,
#    'train_metrics/JaccardIndex': 0.820042610168457},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8233922123908997,
#    'valid_metrics/Accuracy': 0.9241000413894653,
#    'valid_metrics/Dice': 0.8233921527862549,
#    'valid_metrics/Precision': 0.8821150660514832,
#    'valid_metrics/Recall': 0.771999716758728,
#    'valid_metrics/Specificity': 0.9693244099617004,
#    'valid_metrics/JaccardIndex': 0.8037928342819214}},
#  {'tr_loss': 0.009700132561616661,
#   'vl_loss': 0.01068017485778074,
#   'tr_metrics': {'train_metrics/F1Score': 0.8381884098052979,
#    'train_metrics/Accuracy': 0.9342522621154785,
#    'train_metrics/Dice': 0.8381884098052979,
#    'train_metrics/Precision': 0.8710992336273193,
#    'train_metrics/Recall': 0.8076738119125366,
#    'train_metrics/Specificity': 0.9680696129798889,
#    'train_metrics/JaccardIndex': 0.8211039304733276},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8279333114624023,
#    'valid_metrics/Accuracy': 0.9239585399627686,
#    'valid_metrics/Dice': 0.8279333114624023,
#    'valid_metrics/Precision': 0.8599330186843872,
#    'valid_metrics/Recall': 0.7982296943664551,
#    'valid_metrics/Specificity': 0.9613418579101562,
#    'valid_metrics/JaccardIndex': 0.8066599369049072}},
#  {'tr_loss': 0.009572519902806964,
#   'vl_loss': 0.010725474862460924,
#   'tr_metrics': {'train_metrics/F1Score': 0.839548647403717,
#    'train_metrics/Accuracy': 0.9347771406173706,
#    'train_metrics/Dice': 0.839548647403717,
#    'train_metrics/Precision': 0.8721117377281189,
#    'train_metrics/Recall': 0.8093296885490417,
#    'train_metrics/Specificity': 0.9682923555374146,
#    'train_metrics/JaccardIndex': 0.8224126100540161},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8252674341201782,
#    'valid_metrics/Accuracy': 0.9244349598884583,
#    'valid_metrics/Dice': 0.8252674341201782,
#    'valid_metrics/Precision': 0.8778710961341858,
#    'valid_metrics/Recall': 0.7786116003990173,
#    'valid_metrics/Specificity': 0.9677929878234863,
#    'valid_metrics/JaccardIndex': 0.805268406867981}},
#  {'tr_loss': 0.009498104919517828,
#   'vl_loss': 0.010210783339490302,
#   'tr_metrics': {'train_metrics/F1Score': 0.8409329056739807,
#    'train_metrics/Accuracy': 0.9353225827217102,
#    'train_metrics/Dice': 0.8409328460693359,
#    'train_metrics/Precision': 0.8732979893684387,
#    'train_metrics/Recall': 0.8108810186386108,
#    'train_metrics/Specificity': 0.9685690999031067,
#    'train_metrics/JaccardIndex': 0.8237552046775818},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8320419192314148,
#    'valid_metrics/Accuracy': 0.9269928336143494,
#    'valid_metrics/Dice': 0.8320419788360596,
#    'valid_metrics/Precision': 0.8800238370895386,
#    'valid_metrics/Recall': 0.7890217900276184,
#    'valid_metrics/Specificity': 0.9680160880088806,
#    'valid_metrics/JaccardIndex': 0.8116332292556763}},
#  {'tr_loss': 0.00938194385696377,
#   'vl_loss': 0.010324532446598915,
#   'tr_metrics': {'train_metrics/F1Score': 0.8434774875640869,
#    'train_metrics/Accuracy': 0.9363054633140564,
#    'train_metrics/Dice': 0.8434774875640869,
#    'train_metrics/Precision': 0.875174343585968,
#    'train_metrics/Recall': 0.8139963150024414,
#    'train_metrics/Specificity': 0.9689822196960449,
#    'train_metrics/JaccardIndex': 0.8262157440185547},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8338172435760498,
#    'valid_metrics/Accuracy': 0.9262546896934509,
#    'valid_metrics/Dice': 0.833817183971405,
#    'valid_metrics/Precision': 0.8622138500213623,
#    'valid_metrics/Recall': 0.8072314262390137,
#    'valid_metrics/Specificity': 0.9616442322731018,
#    'valid_metrics/JaccardIndex': 0.8122556209564209}},
#  {'tr_loss': 0.009353636454575319,
#   'vl_loss': 0.010183816581504225,
#   'tr_metrics': {'train_metrics/F1Score': 0.8431693911552429,
#    'train_metrics/Accuracy': 0.9361572265625,
#    'train_metrics/Dice': 0.8431693911552429,
#    'train_metrics/Precision': 0.8745179772377014,
#    'train_metrics/Recall': 0.8139904737472534,
#    'train_metrics/Specificity': 0.9687959551811218,
#    'train_metrics/JaccardIndex': 0.8258960843086243},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8392229676246643,
#    'valid_metrics/Accuracy': 0.928045928478241,
#    'valid_metrics/Dice': 0.8392229676246643,
#    'valid_metrics/Precision': 0.8600460290908813,
#    'valid_metrics/Recall': 0.8193844556808472,
#    'valid_metrics/Specificity': 0.9603545069694519,
#    'valid_metrics/JaccardIndex': 0.8171965479850769}},
#  {'tr_loss': 0.009201093689222966,
#   'vl_loss': 0.010987864037738344,
#   'tr_metrics': {'train_metrics/F1Score': 0.8471888303756714,
#    'train_metrics/Accuracy': 0.9377424716949463,
#    'train_metrics/Dice': 0.8471888303756714,
#    'train_metrics/Precision': 0.8779147267341614,
#    'train_metrics/Recall': 0.8185408711433411,
#    'train_metrics/Specificity': 0.9695890545845032,
#    'train_metrics/JaccardIndex': 0.8298233151435852},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8180432915687561,
#    'valid_metrics/Accuracy': 0.9237424731254578,
#    'valid_metrics/Dice': 0.8180432915687561,
#    'valid_metrics/Precision': 0.9026392102241516,
#    'valid_metrics/Recall': 0.7479453682899475,
#    'valid_metrics/Specificity': 0.976012647151947,
#    'valid_metrics/JaccardIndex': 0.800037682056427}},
#  {'tr_loss': 0.009138203106984783,
#   'vl_loss': 0.010791866353292262,
#   'tr_metrics': {'train_metrics/F1Score': 0.8477438688278198,
#    'train_metrics/Accuracy': 0.9379892945289612,
#    'train_metrics/Dice': 0.847743809223175,
#    'train_metrics/Precision': 0.8788049817085266,
#    'train_metrics/Recall': 0.8188035488128662,
#    'train_metrics/Specificity': 0.969831645488739,
#    'train_metrics/JaccardIndex': 0.8303878307342529},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8296220898628235,
#    'valid_metrics/Accuracy': 0.9230419993400574,
#    'valid_metrics/Dice': 0.8296220898628235,
#    'valid_metrics/Precision': 0.8420853018760681,
#    'valid_metrics/Recall': 0.817522406578064,
#    'valid_metrics/Specificity': 0.9544163942337036,
#    'valid_metrics/JaccardIndex': 0.8070739507675171}},
#  {'tr_loss': 0.009175415326310091,
#   'vl_loss': 0.010786490414190936,
#   'tr_metrics': {'train_metrics/F1Score': 0.8474621772766113,
#    'train_metrics/Accuracy': 0.937716007232666,
#    'train_metrics/Dice': 0.8474621772766113,
#    'train_metrics/Precision': 0.876118540763855,
#    'train_metrics/Recall': 0.8206210732460022,
#    'train_metrics/Specificity': 0.9689998030662537,
#    'train_metrics/JaccardIndex': 0.8299931287765503},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8262154459953308,
#    'valid_metrics/Accuracy': 0.9252505898475647,
#    'valid_metrics/Dice': 0.8262155055999756,
#    'valid_metrics/Precision': 0.8842905163764954,
#    'valid_metrics/Recall': 0.7752984166145325,
#    'valid_metrics/Specificity': 0.9698362350463867,
#    'valid_metrics/JaccardIndex': 0.8064943552017212}},
#  {'tr_loss': 0.00906074398476887,
#   'vl_loss': 0.01016390832450284,
#   'tr_metrics': {'train_metrics/F1Score': 0.848766565322876,
#    'train_metrics/Accuracy': 0.9384014010429382,
#    'train_metrics/Dice': 0.8487665057182312,
#    'train_metrics/Precision': 0.8797957897186279,
#    'train_metrics/Recall': 0.8198514580726624,
#    'train_metrics/Specificity': 0.9700737595558167,
#    'train_metrics/JaccardIndex': 0.8313977718353271},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8376500010490417,
#    'valid_metrics/Accuracy': 0.9271245002746582,
#    'valid_metrics/Dice': 0.8376500010490417,
#    'valid_metrics/Precision': 0.8557533621788025,
#    'valid_metrics/Recall': 0.8202967047691345,
#    'valid_metrics/Specificity': 0.9588878154754639,
#    'valid_metrics/JaccardIndex': 0.8154518604278564}},
#  {'tr_loss': 0.008920616588296149,
#   'vl_loss': 0.010211386196459123,
#   'tr_metrics': {'train_metrics/F1Score': 0.8512093424797058,
#    'train_metrics/Accuracy': 0.9393134713172913,
#    'train_metrics/Dice': 0.8512094020843506,
#    'train_metrics/Precision': 0.881037175655365,
#    'train_metrics/Recall': 0.8233351111412048,
#    'train_metrics/Specificity': 0.9702989459037781,
#    'train_metrics/JaccardIndex': 0.8337637186050415},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8346837759017944,
#    'valid_metrics/Accuracy': 0.9282019734382629,
#    'valid_metrics/Dice': 0.8346837759017944,
#    'valid_metrics/Precision': 0.8836531043052673,
#    'valid_metrics/Recall': 0.7908569574356079,
#    'valid_metrics/Specificity': 0.9690391421318054,
#    'valid_metrics/JaccardIndex': 0.8142898082733154}},
#  {'tr_loss': 0.00893998750621458,
#   'vl_loss': 0.010036434654621083,
#   'tr_metrics': {'train_metrics/F1Score': 0.850835382938385,
#    'train_metrics/Accuracy': 0.9392063617706299,
#    'train_metrics/Dice': 0.850835382938385,
#    'train_metrics/Precision': 0.8813555836677551,
#    'train_metrics/Recall': 0.822358250617981,
#    'train_metrics/Specificity': 0.9704242944717407,
#    'train_metrics/JaccardIndex': 0.8334248065948486},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8420328497886658,
#    'valid_metrics/Accuracy': 0.9287325739860535,
#    'valid_metrics/Dice': 0.8420328497886658,
#    'valid_metrics/Precision': 0.8557303547859192,
#    'valid_metrics/Recall': 0.828766942024231,
#    'valid_metrics/Specificity': 0.9584555625915527,
#    'valid_metrics/JaccardIndex': 0.8195931911468506}},
#  {'tr_loss': 0.008758191286634971,
#   'vl_loss': 0.010052258860765736,
#   'tr_metrics': {'train_metrics/F1Score': 0.8541296720504761,
#    'train_metrics/Accuracy': 0.9404118657112122,
#    'train_metrics/Dice': 0.8541297316551208,
#    'train_metrics/Precision': 0.8825905323028564,
#    'train_metrics/Recall': 0.8274470567703247,
#    'train_metrics/Specificity': 0.9705922603607178,
#    'train_metrics/JaccardIndex': 0.83660888671875},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8367846012115479,
#    'valid_metrics/Accuracy': 0.9297623634338379,
#    'valid_metrics/Dice': 0.8367846012115479,
#    'valid_metrics/Precision': 0.8951039910316467,
#    'valid_metrics/Recall': 0.7855998277664185,
#    'valid_metrics/Specificity': 0.9726265668869019,
#    'valid_metrics/JaccardIndex': 0.8168556094169617}},
#  {'tr_loss': 0.008690178069509258,
#   'vl_loss': 0.010317252754704832,
#   'tr_metrics': {'train_metrics/F1Score': 0.8556011319160461,
#    'train_metrics/Accuracy': 0.9411407113075256,
#    'train_metrics/Dice': 0.8556011319160461,
#    'train_metrics/Precision': 0.8861631155014038,
#    'train_metrics/Recall': 0.8270769715309143,
#    'train_metrics/Specificity': 0.97161465883255,
#    'train_metrics/JaccardIndex': 0.8381757736206055},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8377940654754639,
#    'valid_metrics/Accuracy': 0.9268361330032349,
#    'valid_metrics/Dice': 0.8377940654754639,
#    'valid_metrics/Precision': 0.8516141772270203,
#    'valid_metrics/Recall': 0.8244153261184692,
#    'valid_metrics/Specificity': 0.9572891592979431,
#    'valid_metrics/JaccardIndex': 0.8153284788131714}},
#  {'tr_loss': 0.008572331424956479,
#   'vl_loss': 0.010479828457862253,
#   'tr_metrics': {'train_metrics/F1Score': 0.858058512210846,
#    'train_metrics/Accuracy': 0.94203782081604,
#    'train_metrics/Dice': 0.8580584526062012,
#    'train_metrics/Precision': 0.8869943618774414,
#    'train_metrics/Recall': 0.8309507966041565,
#    'train_metrics/Specificity': 0.9717165231704712,
#    'train_metrics/JaccardIndex': 0.8405646681785583},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8326989412307739,
#    'valid_metrics/Accuracy': 0.9270431399345398,
#    'valid_metrics/Dice': 0.8326989412307739,
#    'valid_metrics/Precision': 0.8775626420974731,
#    'valid_metrics/Recall': 0.7921993136405945,
#    'valid_metrics/Specificity': 0.967136561870575,
#    'valid_metrics/JaccardIndex': 0.8121062517166138}},
#  {'tr_loss': 0.008578993413422883,
#   'vl_loss': 0.010242051275943237,
#   'tr_metrics': {'train_metrics/F1Score': 0.8567126989364624,
#    'train_metrics/Accuracy': 0.9414969682693481,
#    'train_metrics/Dice': 0.8567127585411072,
#    'train_metrics/Precision': 0.8857420086860657,
#    'train_metrics/Recall': 0.829525887966156,
#    'train_metrics/Specificity': 0.9714117050170898,
#    'train_metrics/JaccardIndex': 0.8392189741134644},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8314756751060486,
#    'valid_metrics/Accuracy': 0.9285494089126587,
#    'valid_metrics/Dice': 0.8314756155014038,
#    'valid_metrics/Precision': 0.9048894643783569,
#    'valid_metrics/Recall': 0.7690800428390503,
#    'valid_metrics/Specificity': 0.9759648442268372,
#    'valid_metrics/JaccardIndex': 0.8124103546142578}},
#  {'tr_loss': 0.008453559277184082,
#   'vl_loss': 0.010354125904616932,
#   'tr_metrics': {'train_metrics/F1Score': 0.8597108721733093,
#    'train_metrics/Accuracy': 0.9426940083503723,
#    'train_metrics/Dice': 0.8597108721733093,
#    'train_metrics/Precision': 0.8883952498435974,
#    'train_metrics/Recall': 0.8328208327293396,
#    'train_metrics/Specificity': 0.9720483422279358,
#    'train_metrics/JaccardIndex': 0.842214822769165},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8345275521278381,
#    'valid_metrics/Accuracy': 0.9283050894737244,
#    'valid_metrics/Dice': 0.8345276117324829,
#    'valid_metrics/Precision': 0.885847806930542,
#    'valid_metrics/Recall': 0.7888280749320984,
#    'valid_metrics/Specificity': 0.9697761535644531,
#    'valid_metrics/JaccardIndex': 0.8142626285552979}},
#  {'tr_loss': 0.008561880605875132,
#   'vl_loss': 0.010188060496218187,
#   'tr_metrics': {'train_metrics/F1Score': 0.8578615784645081,
#    'train_metrics/Accuracy': 0.9419900178909302,
#    'train_metrics/Dice': 0.8578615784645081,
#    'train_metrics/Precision': 0.887322723865509,
#    'train_metrics/Recall': 0.8302938938140869,
#    'train_metrics/Specificity': 0.9718313813209534,
#    'train_metrics/JaccardIndex': 0.8403906226158142},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8377634286880493,
#    'valid_metrics/Accuracy': 0.9288325905799866,
#    'valid_metrics/Dice': 0.8377634286880493,
#    'valid_metrics/Precision': 0.8771780729293823,
#    'valid_metrics/Recall': 0.8017385601997375,
#    'valid_metrics/Specificity': 0.9666217565536499,
#    'valid_metrics/JaccardIndex': 0.816815972328186}},
#  {'tr_loss': 0.008284556093951559,
#   'vl_loss': 0.010153631489134203,
#   'tr_metrics': {'train_metrics/F1Score': 0.8626713752746582,
#    'train_metrics/Accuracy': 0.9438387155532837,
#    'train_metrics/Dice': 0.8626713156700134,
#    'train_metrics/Precision': 0.8903604745864868,
#    'train_metrics/Recall': 0.8366524577140808,
#    'train_metrics/Specificity': 0.9724751114845276,
#    'train_metrics/JaccardIndex': 0.8451583385467529},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8325892090797424,
#    'valid_metrics/Accuracy': 0.9290351271629333,
#    'valid_metrics/Dice': 0.8325892090797424,
#    'valid_metrics/Precision': 0.9063053727149963,
#    'valid_metrics/Recall': 0.769962728023529,
#    'valid_metrics/Specificity': 0.9763324856758118,
#    'valid_metrics/JaccardIndex': 0.8135108947753906}},
#  {'tr_loss': 0.00825389028262583,
#   'vl_loss': 0.010710349928544525,
#   'tr_metrics': {'train_metrics/F1Score': 0.864005446434021,
#    'train_metrics/Accuracy': 0.9443626999855042,
#    'train_metrics/Dice': 0.8640053272247314,
#    'train_metrics/Precision': 0.8913708329200745,
#    'train_metrics/Recall': 0.8382701873779297,
#    'train_metrics/Specificity': 0.9727069735527039,
#    'train_metrics/JaccardIndex': 0.8464950919151306},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8293017745018005,
#    'valid_metrics/Accuracy': 0.9274490475654602,
#    'valid_metrics/Dice': 0.8293017745018005,
#    'valid_metrics/Precision': 0.8999154567718506,
#    'valid_metrics/Recall': 0.7689635157585144,
#    'valid_metrics/Specificity': 0.974571943283081,
#    'valid_metrics/JaccardIndex': 0.8101547956466675}},
#  {'tr_loss': 0.008217759937376359,
#   'vl_loss': 0.009917562187408389,
#   'tr_metrics': {'train_metrics/F1Score': 0.8642817139625549,
#    'train_metrics/Accuracy': 0.9445488452911377,
#    'train_metrics/Dice': 0.8642817139625549,
#    'train_metrics/Precision': 0.8929077982902527,
#    'train_metrics/Recall': 0.8374340534210205,
#    'train_metrics/Specificity': 0.973166286945343,
#    'train_metrics/JaccardIndex': 0.8468295335769653},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8418553471565247,
#    'valid_metrics/Accuracy': 0.9303992986679077,
#    'valid_metrics/Dice': 0.8418553471565247,
#    'valid_metrics/Precision': 0.87831050157547,
#    'valid_metrics/Recall': 0.8083057999610901,
#    'valid_metrics/Specificity': 0.9667016267776489,
#    'valid_metrics/JaccardIndex': 0.8207368850708008}},
#  {'tr_loss': 0.008011879248046843,
#   'vl_loss': 0.010885330305423976,
#   'tr_metrics': {'train_metrics/F1Score': 0.8674163818359375,
#    'train_metrics/Accuracy': 0.9456796050071716,
#    'train_metrics/Dice': 0.8674163818359375,
#    'train_metrics/Precision': 0.8935157060623169,
#    'train_metrics/Recall': 0.8427984714508057,
#    'train_metrics/Specificity': 0.9731659293174744,
#    'train_metrics/JaccardIndex': 0.8499076962471008},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8348434567451477,
#    'valid_metrics/Accuracy': 0.9221269488334656,
#    'valid_metrics/Dice': 0.8348433971405029,
#    'valid_metrics/Precision': 0.812216579914093,
#    'valid_metrics/Recall': 0.858767032623291,
#    'valid_metrics/Specificity': 0.9409658908843994,
#    'valid_metrics/JaccardIndex': 0.8097758293151855}},
#  {'tr_loss': 0.008095607242082596,
#   'vl_loss': 0.010202207376022596,
#   'tr_metrics': {'train_metrics/F1Score': 0.8656153678894043,
#    'train_metrics/Accuracy': 0.9451459646224976,
#    'train_metrics/Dice': 0.8656153082847595,
#    'train_metrics/Precision': 0.8951929807662964,
#    'train_metrics/Recall': 0.8379296660423279,
#    'train_metrics/Specificity': 0.9737904071807861,
#    'train_metrics/JaccardIndex': 0.8482229709625244},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8402295708656311,
#    'valid_metrics/Accuracy': 0.9298471808433533,
#    'valid_metrics/Dice': 0.8402295708656311,
#    'valid_metrics/Precision': 0.8788386583328247,
#    'valid_metrics/Recall': 0.804870069026947,
#    'valid_metrics/Specificity': 0.9670069217681885,
#    'valid_metrics/JaccardIndex': 0.819229245185852}},
#  {'tr_loss': 0.008085387483362324,
#   'vl_loss': 0.010013584651657054,
#   'tr_metrics': {'train_metrics/F1Score': 0.8665990829467773,
#    'train_metrics/Accuracy': 0.9454432129859924,
#    'train_metrics/Dice': 0.8665991425514221,
#    'train_metrics/Precision': 0.89438396692276,
#    'train_metrics/Recall': 0.8404885530471802,
#    'train_metrics/Specificity': 0.9734835028648376,
#    'train_metrics/JaccardIndex': 0.8491470217704773},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8416667580604553,
#    'valid_metrics/Accuracy': 0.9314761161804199,
#    'valid_metrics/Dice': 0.8416668176651001,
#    'valid_metrics/Precision': 0.8945661783218384,
#    'valid_metrics/Recall': 0.7946744561195374,
#    'valid_metrics/Specificity': 0.9721516966819763,
#    'valid_metrics/JaccardIndex': 0.8214178085327148}},
#  {'tr_loss': 0.008008939428537181,
#   'vl_loss': 0.010258001512686028,
#   'tr_metrics': {'train_metrics/F1Score': 0.8677291870117188,
#    'train_metrics/Accuracy': 0.9458253383636475,
#    'train_metrics/Dice': 0.8677291870117188,
#    'train_metrics/Precision': 0.8941445350646973,
#    'train_metrics/Recall': 0.8428298234939575,
#    'train_metrics/Specificity': 0.9733421206474304,
#    'train_metrics/JaccardIndex': 0.8502399921417236},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8384111523628235,
#    'valid_metrics/Accuracy': 0.9278793334960938,
#    'valid_metrics/Dice': 0.8384111523628235,
#    'valid_metrics/Precision': 0.861681342124939,
#    'valid_metrics/Recall': 0.8163647651672363,
#    'valid_metrics/Specificity': 0.9610362648963928,
#    'valid_metrics/JaccardIndex': 0.8165296316146851}},
#  {'tr_loss': 0.007941412974467127,
#   'vl_loss': 0.009847619380212199,
#   'tr_metrics': {'train_metrics/F1Score': 0.8691652417182922,
#    'train_metrics/Accuracy': 0.9464494585990906,
#    'train_metrics/Dice': 0.8691652417182922,
#    'train_metrics/Precision': 0.896263062953949,
#    'train_metrics/Recall': 0.843657910823822,
#    'train_metrics/Specificity': 0.9739118218421936,
#    'train_metrics/JaccardIndex': 0.8517341613769531},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8424198031425476,
#    'valid_metrics/Accuracy': 0.931241512298584,
#    'valid_metrics/Dice': 0.8424198031425476,
#    'valid_metrics/Precision': 0.8872248530387878,
#    'valid_metrics/Recall': 0.8019225597381592,
#    'valid_metrics/Specificity': 0.9696922302246094,
#    'valid_metrics/JaccardIndex': 0.8217504024505615}},
#  {'tr_loss': 0.007795745019413551,
#   'vl_loss': 0.009938898363283702,
#   'tr_metrics': {'train_metrics/F1Score': 0.8711903691291809,
#    'train_metrics/Accuracy': 0.9472527503967285,
#    'train_metrics/Dice': 0.8711902499198914,
#    'train_metrics/Precision': 0.8978875279426575,
#    'train_metrics/Recall': 0.8460349440574646,
#    'train_metrics/Specificity': 0.9742945432662964,
#    'train_metrics/JaccardIndex': 0.8537895083427429},
#   'vl_metrics': {'valid_metrics/F1Score': 0.839773952960968,
#    'valid_metrics/Accuracy': 0.9310775995254517,
#    'valid_metrics/Dice': 0.839773952960968,
#    'valid_metrics/Precision': 0.8987295627593994,
#    'valid_metrics/Recall': 0.7880769968032837,
#    'valid_metrics/Specificity': 0.9735962748527527,
#    'valid_metrics/JaccardIndex': 0.8198434710502625}},
#  {'tr_loss': 0.007619954285932803,
#   'vl_loss': 0.010041641632389839,
#   'tr_metrics': {'train_metrics/F1Score': 0.874156653881073,
#    'train_metrics/Accuracy': 0.9484056830406189,
#    'train_metrics/Dice': 0.8741567134857178,
#    'train_metrics/Precision': 0.8998016715049744,
#    'train_metrics/Recall': 0.8499329686164856,
#    'train_metrics/Specificity': 0.9747142195701599,
#    'train_metrics/JaccardIndex': 0.8567938804626465},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8459139466285706,
#    'valid_metrics/Accuracy': 0.9303597807884216,
#    'valid_metrics/Dice': 0.8459139466285706,
#    'valid_metrics/Precision': 0.8581004738807678,
#    'valid_metrics/Recall': 0.8340687155723572,
#    'valid_metrics/Specificity': 0.9589902758598328,
#    'valid_metrics/JaccardIndex': 0.8234372138977051}},
#  {'tr_loss': 0.007673459749453324,
#   'vl_loss': 0.010007136411475858,
#   'tr_metrics': {'train_metrics/F1Score': 0.8743345737457275,
#    'train_metrics/Accuracy': 0.9484239816665649,
#    'train_metrics/Dice': 0.8743345737457275,
#    'train_metrics/Precision': 0.8989770412445068,
#    'train_metrics/Recall': 0.8510069847106934,
#    'train_metrics/Specificity': 0.974450409412384,
#    'train_metrics/JaccardIndex': 0.8569366931915283},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8426744937896729,
#    'valid_metrics/Accuracy': 0.9320996999740601,
#    'valid_metrics/Dice': 0.8426744937896729,
#    'valid_metrics/Precision': 0.8984299302101135,
#    'valid_metrics/Recall': 0.7934348583221436,
#    'valid_metrics/Specificity': 0.9733292460441589,
#    'valid_metrics/JaccardIndex': 0.8225650787353516}},
#  {'tr_loss': 0.0075516467929379015,
#   'vl_loss': 0.010241830735880897,
#   'tr_metrics': {'train_metrics/F1Score': 0.8756093382835388,
#    'train_metrics/Accuracy': 0.9490296840667725,
#    'train_metrics/Dice': 0.8756093978881836,
#    'train_metrics/Precision': 0.901828944683075,
#    'train_metrics/Recall': 0.8508713245391846,
#    'train_metrics/Specificity': 0.9752541780471802,
#    'train_metrics/JaccardIndex': 0.858314037322998},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8446215391159058,
#    'valid_metrics/Accuracy': 0.929081916809082,
#    'valid_metrics/Dice': 0.844621479511261,
#    'valid_metrics/Precision': 0.8482521772384644,
#    'valid_metrics/Recall': 0.841021716594696,
#    'valid_metrics/Specificity': 0.9552650451660156,
#    'valid_metrics/JaccardIndex': 0.8215913772583008}},
#  {'tr_loss': 0.007416866100380407,
#   'vl_loss': 0.010215389128760022,
#   'tr_metrics': {'train_metrics/F1Score': 0.8787718415260315,
#    'train_metrics/Accuracy': 0.9502732157707214,
#    'train_metrics/Dice': 0.8787718415260315,
#    'train_metrics/Precision': 0.904077410697937,
#    'train_metrics/Recall': 0.854844331741333,
#    'train_metrics/Specificity': 0.9757684469223022,
#    'train_metrics/JaccardIndex': 0.8615493178367615},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8449152708053589,
#    'valid_metrics/Accuracy': 0.9314174652099609,
#    'valid_metrics/Dice': 0.8449152112007141,
#    'valid_metrics/Precision': 0.8769389390945435,
#    'valid_metrics/Recall': 0.8151479959487915,
#    'valid_metrics/Specificity': 0.9659881591796875,
#    'valid_metrics/JaccardIndex': 0.8235678672790527}},
#  {'tr_loss': 0.007503285787527555,
#   'vl_loss': 0.010186621735886487,
#   'tr_metrics': {'train_metrics/F1Score': 0.8767129778862,
#    'train_metrics/Accuracy': 0.949379563331604,
#    'train_metrics/Dice': 0.8767129182815552,
#    'train_metrics/Precision': 0.9010359644889832,
#    'train_metrics/Recall': 0.8536686897277832,
#    'train_metrics/Specificity': 0.9749501943588257,
#    'train_metrics/JaccardIndex': 0.8593788146972656},
#   'vl_metrics': {'valid_metrics/F1Score': 0.837213933467865,
#    'valid_metrics/Accuracy': 0.9296764731407166,
#    'valid_metrics/Dice': 0.8372138738632202,
#    'valid_metrics/Precision': 0.8916536569595337,
#    'valid_metrics/Recall': 0.7890392541885376,
#    'valid_metrics/Specificity': 0.9714925289154053,
#    'valid_metrics/JaccardIndex': 0.8170793652534485}},
#  {'tr_loss': 0.007303125838192369,
#   'vl_loss': 0.010306192407362939,
#   'tr_metrics': {'train_metrics/F1Score': 0.8800985813140869,
#    'train_metrics/Accuracy': 0.950747549533844,
#    'train_metrics/Dice': 0.8800985813140869,
#    'train_metrics/Precision': 0.9040871262550354,
#    'train_metrics/Recall': 0.8573501706123352,
#    'train_metrics/Specificity': 0.9757001399993896,
#    'train_metrics/JaccardIndex': 0.8628759384155273},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8399884700775146,
#    'valid_metrics/Accuracy': 0.9301526546478271,
#    'valid_metrics/Dice': 0.8399884700775146,
#    'valid_metrics/Precision': 0.8842727541923523,
#    'valid_metrics/Recall': 0.7999281883239746,
#    'valid_metrics/Specificity': 0.968872606754303,
#    'valid_metrics/JaccardIndex': 0.8192967176437378}},
#  {'tr_loss': 0.00725178984725032,
#   'vl_loss': 0.009903333002420927,
#   'tr_metrics': {'train_metrics/F1Score': 0.8805767893791199,
#    'train_metrics/Accuracy': 0.9509692788124084,
#    'train_metrics/Dice': 0.8805768489837646,
#    'train_metrics/Precision': 0.905070424079895,
#    'train_metrics/Recall': 0.8573740124702454,
#    'train_metrics/Specificity': 0.9759747385978699,
#    'train_metrics/JaccardIndex': 0.8633924722671509},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8461722731590271,
#    'valid_metrics/Accuracy': 0.9315447211265564,
#    'valid_metrics/Dice': 0.8461722731590271,
#    'valid_metrics/Precision': 0.8723674416542053,
#    'valid_metrics/Recall': 0.8215043544769287,
#    'valid_metrics/Specificity': 0.9642633199691772,
#    'valid_metrics/JaccardIndex': 0.8245137929916382}},
# ...
#    'valid_metrics/Dice': 0.8454691171646118,
#    'valid_metrics/Precision': 0.867370069026947,
#    'valid_metrics/Recall': 0.8246469497680664,
#    'valid_metrics/Specificity': 0.9625072479248047,
#    'valid_metrics/JaccardIndex': 0.8235580325126648}},
#  {'tr_loss': 0.0052614381921685435,
#   'vl_loss': 0.011142714225963966,
#   'tr_metrics': {'train_metrics/F1Score': 0.9156168103218079,
#    'train_metrics/Accuracy': 0.9650331139564514,
#    'train_metrics/Dice': 0.9156166911125183,
#    'train_metrics/Precision': 0.9320173263549805,
#    'train_metrics/Recall': 0.8997834920883179,
#    'train_metrics/Specificity': 0.9824655652046204,
#    'train_metrics/JaccardIndex': 0.9006064534187317},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8429776430130005,
#    'valid_metrics/Accuracy': 0.9313064217567444,
#    'valid_metrics/Dice': 0.8429777026176453,
#    'valid_metrics/Precision': 0.8852675557136536,
#    'valid_metrics/Recall': 0.8045440912246704,
#    'valid_metrics/Specificity': 0.9689970016479492,
#    'valid_metrics/JaccardIndex': 0.8221757411956787}},
#  {'tr_loss': 0.005218838066498931,
#   'vl_loss': 0.010904118102259618,
#   'tr_metrics': {'train_metrics/F1Score': 0.9160553216934204,
#    'train_metrics/Accuracy': 0.9652321338653564,
#    'train_metrics/Dice': 0.9160552620887756,
#    'train_metrics/Precision': 0.9329467415809631,
#    'train_metrics/Recall': 0.8997645378112793,
#    'train_metrics/Specificity': 0.9827229380607605,
#    'train_metrics/JaccardIndex': 0.9011024832725525},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8472151756286621,
#    'valid_metrics/Accuracy': 0.9316755533218384,
#    'valid_metrics/Dice': 0.8472151756286621,
#    'valid_metrics/Precision': 0.8689413070678711,
#    'valid_metrics/Recall': 0.8265489935874939,
#    'valid_metrics/Specificity': 0.9629331231117249,
#    'valid_metrics/JaccardIndex': 0.8253183960914612}},
#  {'tr_loss': 0.005165239410172153,
#   'vl_loss': 0.011116403244924822,
#   'tr_metrics': {'train_metrics/F1Score': 0.9172319173812866,
#    'train_metrics/Accuracy': 0.9656980633735657,
#    'train_metrics/Dice': 0.9172319173812866,
#    'train_metrics/Precision': 0.9335406422615051,
#    'train_metrics/Recall': 0.9014832377433777,
#    'train_metrics/Specificity': 0.9828541874885559,
#    'train_metrics/JaccardIndex': 0.9023830890655518},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8450032472610474,
#    'valid_metrics/Accuracy': 0.9319330453872681,
#    'valid_metrics/Dice': 0.8450033068656921,
#    'valid_metrics/Precision': 0.8836871385574341,
#    'valid_metrics/Recall': 0.8095641732215881,
#    'valid_metrics/Specificity': 0.9683172702789307,
#    'valid_metrics/JaccardIndex': 0.8240166902542114}},
#  {'tr_loss': 0.00515793140916046,
#   'vl_loss': 0.011237047648625485,
#   'tr_metrics': {'train_metrics/F1Score': 0.9172911047935486,
#    'train_metrics/Accuracy': 0.9657241702079773,
#    'train_metrics/Dice': 0.9172910451889038,
#    'train_metrics/Precision': 0.9336439967155457,
#    'train_metrics/Recall': 0.9015011191368103,
#    'train_metrics/Specificity': 0.9828823208808899,
#    'train_metrics/JaccardIndex': 0.9024494886398315},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8449971675872803,
#    'valid_metrics/Accuracy': 0.9318571090698242,
#    'valid_metrics/Dice': 0.8449971079826355,
#    'valid_metrics/Precision': 0.8826451301574707,
#    'valid_metrics/Recall': 0.8104293942451477,
#    'valid_metrics/Specificity': 0.9679614901542664,
#    'valid_metrics/JaccardIndex': 0.823955237865448}},
#  {'tr_loss': 0.005138715818914336,
#   'vl_loss': 0.011104855006812391,
#   'tr_metrics': {'train_metrics/F1Score': 0.917387843132019,
#    'train_metrics/Accuracy': 0.9657583236694336,
#    'train_metrics/Dice': 0.9173877835273743,
#    'train_metrics/Precision': 0.9335755705833435,
#    'train_metrics/Recall': 0.9017519354820251,
#    'train_metrics/Specificity': 0.9828587174415588,
#    'train_metrics/JaccardIndex': 0.9025517702102661},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8474071621894836,
#    'valid_metrics/Accuracy': 0.9321147203445435,
#    'valid_metrics/Dice': 0.8474071621894836,
#    'valid_metrics/Precision': 0.8739197254180908,
#    'valid_metrics/Recall': 0.822455883026123,
#    'valid_metrics/Specificity': 0.964719831943512,
#    'valid_metrics/JaccardIndex': 0.8257821798324585}},
#  {'tr_loss': 0.005088349488453514,
#   'vl_loss': 0.011097592582142261,
#   'tr_metrics': {'train_metrics/F1Score': 0.9186618328094482,
#    'train_metrics/Accuracy': 0.9663044810295105,
#    'train_metrics/Dice': 0.9186617136001587,
#    'train_metrics/Precision': 0.935391366481781,
#    'train_metrics/Recall': 0.9025201201438904,
#    'train_metrics/Specificity': 0.9833455085754395,
#    'train_metrics/JaccardIndex': 0.9039729833602905},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8473607301712036,
#    'valid_metrics/Accuracy': 0.9316028952598572,
#    'valid_metrics/Dice': 0.8473607301712036,
#    'valid_metrics/Precision': 0.8672546744346619,
#    'valid_metrics/Recall': 0.8283590078353882,
#    'valid_metrics/Specificity': 0.9623006582260132,
#    'valid_metrics/JaccardIndex': 0.8253615498542786}},
#  {'tr_loss': 0.004906896572590859,
#   'vl_loss': 0.011266975415489388,
#   'tr_metrics': {'train_metrics/F1Score': 0.9214674830436707,
#    'train_metrics/Accuracy': 0.9674228429794312,
#    'train_metrics/Dice': 0.9214673638343811,
#    'train_metrics/Precision': 0.9369383454322815,
#    'train_metrics/Recall': 0.9064991474151611,
#    'train_metrics/Specificity': 0.9836995005607605,
#    'train_metrics/JaccardIndex': 0.9070484042167664},
#   'vl_metrics': {'valid_metrics/F1Score': 0.845270037651062,
#    'valid_metrics/Accuracy': 0.9306767582893372,
#    'valid_metrics/Dice': 0.8452699780464172,
#    'valid_metrics/Precision': 0.8652545809745789,
#    'valid_metrics/Recall': 0.8261877298355103,
#    'valid_metrics/Specificity': 0.9617447257041931,
#    'valid_metrics/JaccardIndex': 0.8232454061508179}},
#  {'tr_loss': 0.004866834387142139,
#   'vl_loss': 0.011223166522976284,
#   'tr_metrics': {'train_metrics/F1Score': 0.9222066402435303,
#    'train_metrics/Accuracy': 0.9677225351333618,
#    'train_metrics/Dice': 0.9222066402435303,
#    'train_metrics/Precision': 0.9374833106994629,
#    'train_metrics/Recall': 0.9074199199676514,
#    'train_metrics/Specificity': 0.983833372592926,
#    'train_metrics/JaccardIndex': 0.9078648686408997},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8473355174064636,
#    'valid_metrics/Accuracy': 0.9322447776794434,
#    'valid_metrics/Dice': 0.8473354578018188,
#    'valid_metrics/Precision': 0.876070499420166,
#    'valid_metrics/Recall': 0.8204256296157837,
#    'valid_metrics/Specificity': 0.9654921889305115,
#    'valid_metrics/JaccardIndex': 0.8258322477340698}},
#  {'tr_loss': 0.0048571647106369666,
#   'vl_loss': 0.01131522295903055,
#   'tr_metrics': {'train_metrics/F1Score': 0.9221672415733337,
#    'train_metrics/Accuracy': 0.967706561088562,
#    'train_metrics/Dice': 0.9221672415733337,
#    'train_metrics/Precision': 0.9374527931213379,
#    'train_metrics/Recall': 0.9073721170425415,
#    'train_metrics/Specificity': 0.9838258028030396,
#    'train_metrics/JaccardIndex': 0.9078212380409241},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8465273380279541,
#    'valid_metrics/Accuracy': 0.9316546320915222,
#    'valid_metrics/Dice': 0.8465272784233093,
#    'valid_metrics/Precision': 0.8720815181732178,
#    'valid_metrics/Recall': 0.8224280476570129,
#    'valid_metrics/Specificity': 0.964131236076355,
#    'valid_metrics/JaccardIndex': 0.8248372077941895}},
#  {'tr_loss': 0.004815181331919409,
#   'vl_loss': 0.011416359081806824,
#   'tr_metrics': {'train_metrics/F1Score': 0.9228945970535278,
#    'train_metrics/Accuracy': 0.9679962992668152,
#    'train_metrics/Dice': 0.9228945970535278,
#    'train_metrics/Precision': 0.9378262758255005,
#    'train_metrics/Recall': 0.9084309339523315,
#    'train_metrics/Specificity': 0.983910083770752,
#    'train_metrics/JaccardIndex': 0.9086214900016785},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8438462018966675,
#    'valid_metrics/Accuracy': 0.9307900071144104,
#    'valid_metrics/Dice': 0.8438462615013123,
#    'valid_metrics/Precision': 0.8737281560897827,
#    'valid_metrics/Recall': 0.8159406781196594,
#    'valid_metrics/Specificity': 0.9649384617805481,
#    'valid_metrics/JaccardIndex': 0.8223720788955688}},
#  {'tr_loss': 0.004818012252881015,
#   'vl_loss': 0.011376484872550347,
#   'tr_metrics': {'train_metrics/F1Score': 0.9231405854225159,
#    'train_metrics/Accuracy': 0.9680967926979065,
#    'train_metrics/Dice': 0.9231405854225159,
#    'train_metrics/Precision': 0.9380291104316711,
#    'train_metrics/Recall': 0.9087172746658325,
#    'train_metrics/Specificity': 0.9839609861373901,
#    'train_metrics/JaccardIndex': 0.9088941812515259},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8455601334571838,
#    'valid_metrics/Accuracy': 0.9313258528709412,
#    'valid_metrics/Dice': 0.8455601930618286,
#    'valid_metrics/Precision': 0.8724576830863953,
#    'valid_metrics/Recall': 0.8202714920043945,
#    'valid_metrics/Specificity': 0.9643458724021912,
#    'valid_metrics/JaccardIndex': 0.8239341378211975}},
#  {'tr_loss': 0.004784336644571182,
#   'vl_loss': 0.011301758878911094,
#   'tr_metrics': {'train_metrics/F1Score': 0.9235657453536987,
#    'train_metrics/Accuracy': 0.968279242515564,
#    'train_metrics/Dice': 0.9235657453536987,
#    'train_metrics/Precision': 0.9386436343193054,
#    'train_metrics/Recall': 0.9089645743370056,
#    'train_metrics/Specificity': 0.9841260313987732,
#    'train_metrics/JaccardIndex': 0.9093725681304932},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8456063866615295,
#    'valid_metrics/Accuracy': 0.9315049648284912,
#    'valid_metrics/Dice': 0.8456063866615295,
#    'valid_metrics/Precision': 0.8746592402458191,
#    'valid_metrics/Recall': 0.8184215426445007,
#    'valid_metrics/Specificity': 0.9651283621788025,
#    'valid_metrics/JaccardIndex': 0.8241011500358582}},
#  {'tr_loss': 0.004784306461509759,
#   'vl_loss': 0.011516105390826247,
#   'tr_metrics': {'train_metrics/F1Score': 0.9235881567001343,
#    'train_metrics/Accuracy': 0.9682781100273132,
#    'train_metrics/Dice': 0.9235880970954895,
#    'train_metrics/Precision': 0.9383496046066284,
#    'train_metrics/Recall': 0.9092838168144226,
#    'train_metrics/Specificity': 0.9840394258499146,
#    'train_metrics/JaccardIndex': 0.9093896150588989},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8457404375076294,
#    'valid_metrics/Accuracy': 0.930523693561554,
#    'valid_metrics/Dice': 0.8457404375076294,
#    'valid_metrics/Precision': 0.8610140085220337,
#    'valid_metrics/Recall': 0.8309993147850037,
#    'valid_metrics/Specificity': 0.9601155519485474,
#    'valid_metrics/JaccardIndex': 0.8234455585479736}},
#  {'tr_loss': 0.00474400092993886,
#   'vl_loss': 0.011663103983180174,
#   'tr_metrics': {'train_metrics/F1Score': 0.9241921901702881,
#    'train_metrics/Accuracy': 0.9685289859771729,
#    'train_metrics/Dice': 0.9241921901702881,
#    'train_metrics/Precision': 0.9389651417732239,
#    'train_metrics/Recall': 0.909876823425293,
#    'train_metrics/Specificity': 0.9841988682746887,
#    'train_metrics/JaccardIndex': 0.9100633859634399},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8462584614753723,
#    'valid_metrics/Accuracy': 0.930308997631073,
#    'valid_metrics/Dice': 0.8462585210800171,
#    'valid_metrics/Precision': 0.8558408617973328,
#    'valid_metrics/Recall': 0.836888313293457,
#    'valid_metrics/Specificity': 0.9580860137939453,
#    'valid_metrics/JaccardIndex': 0.8236300945281982}},
#  {'tr_loss': 0.004715443401502512,
#   'vl_loss': 0.011599347175145701,
#   'tr_metrics': {'train_metrics/F1Score': 0.9244630932807922,
#    'train_metrics/Accuracy': 0.9686393737792969,
#    'train_metrics/Dice': 0.9244630336761475,
#    'train_metrics/Precision': 0.9391765594482422,
#    'train_metrics/Recall': 0.9102034568786621,
#    'train_metrics/Specificity': 0.9842514991760254,
#    'train_metrics/JaccardIndex': 0.9103641510009766},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8461885452270508,
#    'valid_metrics/Accuracy': 0.9319908022880554,
#    'valid_metrics/Dice': 0.8461886048316956,
#    'valid_metrics/Precision': 0.8784027695655823,
#    'valid_metrics/Recall': 0.8162536025047302,
#    'valid_metrics/Specificity': 0.9664032459259033,
#    'valid_metrics/JaccardIndex': 0.8248628377914429}},
#  {'tr_loss': 0.004708535714747163,
#   'vl_loss': 0.011766214276085029,
#   'tr_metrics': {'train_metrics/F1Score': 0.9250391125679016,
#    'train_metrics/Accuracy': 0.9688637852668762,
#    'train_metrics/Dice': 0.9250391125679016,
#    'train_metrics/Precision': 0.9393033981323242,
#    'train_metrics/Recall': 0.911201536655426,
#    'train_metrics/Specificity': 0.9842692017555237,
#    'train_metrics/JaccardIndex': 0.9109961986541748},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8417489528656006,
#    'valid_metrics/Accuracy': 0.9314320683479309,
#    'valid_metrics/Dice': 0.8417489528656006,
#    'valid_metrics/Precision': 0.8934863805770874,
#    'valid_metrics/Recall': 0.7956752777099609,
#    'valid_metrics/Specificity': 0.971796989440918,
#    'valid_metrics/JaccardIndex': 0.8214403390884399}},
#  {'tr_loss': 0.0046640751190668295,
#   'vl_loss': 0.011529245715890382,
#   'tr_metrics': {'train_metrics/F1Score': 0.9254064559936523,
#    'train_metrics/Accuracy': 0.9690185189247131,
#    'train_metrics/Dice': 0.9254064559936523,
#    'train_metrics/Precision': 0.9397439956665039,
#    'train_metrics/Recall': 0.9114997982978821,
#    'train_metrics/Specificity': 0.98438560962677,
#    'train_metrics/JaccardIndex': 0.9114084243774414},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8433208465576172,
#    'valid_metrics/Accuracy': 0.9294940233230591,
#    'valid_metrics/Dice': 0.8433208465576172,
#    'valid_metrics/Precision': 0.8593096733093262,
#    'valid_metrics/Recall': 0.827916145324707,
#    'valid_metrics/Specificity': 0.9596964716911316,
#    'valid_metrics/JaccardIndex': 0.8210353255271912}},
#  {'tr_loss': 0.00458560289748362,
#   'vl_loss': 0.01156939024601894,
#   'tr_metrics': {'train_metrics/F1Score': 0.9268589019775391,
#    'train_metrics/Accuracy': 0.9696210622787476,
#    'train_metrics/Dice': 0.9268588423728943,
#    'train_metrics/Precision': 0.9411965012550354,
#    'train_metrics/Recall': 0.9129514694213867,
#    'train_metrics/Specificity': 0.9847612977027893,
#    'train_metrics/JaccardIndex': 0.9130338430404663},
#   'vl_metrics': {'valid_metrics/F1Score': 0.845551073551178,
#    'valid_metrics/Accuracy': 0.9311659336090088,
#    'valid_metrics/Dice': 0.845551073551178,
#    'valid_metrics/Precision': 0.8703522682189941,
#    'valid_metrics/Recall': 0.822124183177948,
#    'valid_metrics/Specificity': 0.9635875821113586,
#    'valid_metrics/JaccardIndex': 0.823806643486023}},
#  {'tr_loss': 0.004561518451850604,
#   'vl_loss': 0.011595082965510463,
#   'tr_metrics': {'train_metrics/F1Score': 0.9273359775543213,
#    'train_metrics/Accuracy': 0.969805121421814,
#    'train_metrics/Dice': 0.9273360371589661,
#    'train_metrics/Precision': 0.9412258267402649,
#    'train_metrics/Recall': 0.9138501882553101,
#    'train_metrics/Specificity': 0.9847543239593506,
#    'train_metrics/JaccardIndex': 0.9135578870773315},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8442651033401489,
#    'valid_metrics/Accuracy': 0.9314111471176147,
#    'valid_metrics/Dice': 0.8442651033401489,
#    'valid_metrics/Precision': 0.8801459074020386,
#    'valid_metrics/Recall': 0.8111952543258667,
#    'valid_metrics/Specificity': 0.9671552777290344,
#    'valid_metrics/JaccardIndex': 0.8231239318847656}},
#  {'tr_loss': 0.00454522185951225,
#   'vl_loss': 0.011628511480440504,
#   'tr_metrics': {'train_metrics/F1Score': 0.9274510145187378,
#    'train_metrics/Accuracy': 0.9698657393455505,
#    'train_metrics/Dice': 0.927450954914093,
#    'train_metrics/Precision': 0.9417543411254883,
#    'train_metrics/Recall': 0.9135756492614746,
#    'train_metrics/Specificity': 0.9849044680595398,
#    'train_metrics/JaccardIndex': 0.9136966466903687},
#   'vl_metrics': {'valid_metrics/F1Score': 0.8450546860694885,
#    'valid_metrics/Accuracy': 0.931111216545105,
#    'valid_metrics/Dice': 0.8450546860694885,
#    'valid_metrics/Precision': 0.8720728158950806,
#    'valid_metrics/Recall': 0.8196604251861572,
#    'valid_metrics/Specificity': 0.9642491340637207,
#    'valid_metrics/JaccardIndex': 0.8234301805496216}}]

# %% [markdown]
# ## Save images

# %%
from PIL import Image
import cv2
def skin_plot(img, gt, pred):
    img = np.array(img)
    gt = np.array(gt)
    pred = np.array(pred)
    edged_test = cv2.Canny(pred, 100, 255)
    contours_test, _ = cv2.findContours(edged_test, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
    edged_gt = cv2.Canny(gt, 100, 255)
    contours_gt, _ = cv2.findContours(edged_gt, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
    for cnt_test in contours_test:
        cv2.drawContours(img, [cnt_test], -1, (0, 0, 255), 1)
    for cnt_gt in contours_gt:
        cv2.drawContours(img, [cnt_gt], -1, (0,255,0), 1)
    return img

#---------------------------------------------------------------------------------------------


save_imgs_dir = f"{config['model']['save_dir']}/visualized"

if not os.path.isdir(save_imgs_dir):
    os.mkdir(save_imgs_dir)

with torch.no_grad():
    for batch in tqdm(te_dataloader):
        imgs = batch['image']
        msks = batch['mask']
        ids = batch['id']
        
        preds = best_model(imgs.to(device))
        
        txm = imgs.cpu().numpy()
        tbm = torch.argmax(msks, 1).cpu().numpy()
        tpm = torch.argmax(preds, 1).cpu().numpy()
        tid = ids
        
        for idx in range(len(tbm)):
            img = np.moveaxis(txm[idx, :3], 0, -1)*255.
            img = np.ascontiguousarray(img*255., dtype=np.uint8)
            gt = np.uint8(tbm[idx]*255.)
            pred = np.where(tpm[idx]>0.5, 255, 0)
            pred = np.ascontiguousarray(pred, dtype=np.uint8)
            
            res_img = skin_plot(img, gt, pred)
            
            fid = tid[idx]
            Image.fromarray(img).save(f"{save_imgs_dir}/{fid}_img.png")
            Image.fromarray(gt).save(f"{save_imgs_dir}/{fid}_gt.png")
            Image.fromarray(res_img).save(f"{save_imgs_dir}/{fid}_img_gt_pred.png")
# Out:
# 100%|██████████| 130/130 [00:20<00:00,  6.25it/s]

# %%
f"{config['model']['save_dir']}/visualized"
# Out:
# '../../saved_models/isic2018_unet/visualized'
